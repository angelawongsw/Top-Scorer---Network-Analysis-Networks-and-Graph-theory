# %% [markdown]
# # Top Scorer - Network Analysis via Networks and Graph theory

# %% [markdown]
# <b>Summary:</b> We used networks and graph theory to understand the relationship between each ticket submitted. With this, we managed to map the unlinked customer 100% either via the phone number, email address or order id.

# %% [markdown]
# <b>Problem Statement:</b>
# Customers can contact customer service via various channels such as the livechat function, filling up certain forms or calling in for help. Each time a customer contacts us with a new contact method, a new ticket is automatically generated. A complication arises when the same customer contacts us using different phone numbers or email addresses resulting in multiple tickets for the same issue. Hence, our challenge here is to identify how to merge relevant tickets together to create a complete picture of the customer issue and ultimately determine the RCR

# %% [markdown]
# <b>Dataset: </b>
# You can download the dataset from https://www.kaggle.com/c/scl-2021-da/data

# %% [markdown]
# <b>Solution: </b>
# The solution is simple and sweet, with minor cleaning and used basic network to map out the relationship between each ticket and we managed to formulate the solution and map out the customer network 100% within the timelimit.

# %% [markdown]
# ### First we load the dataset

# %% [raw]
# Each Order ID represents a transaction in Shopee.
# Each Id represents the Ticket Id made to Shopee Customer Service.
# All Phone Numbers are stored without the country code and the country code can be ignored.
# Contacts represent the number of times a user reached out to us in that particular ticket (Email, Call, Livechat etc.)
# If a value is NA means that the system or agent has no record of that value.

# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_json('dataset/contacts.json')
df
# Out:
#             Id                Email         Phone  Contacts  \
# 0            0       gkzAbIy@qq.com                       1
# 1            1                       329442681752         4
# 2            2                         9125983679         0
# 3            3   mdllpYmE@gmail.com                       0
# 4            4                          300364407         2
# ...        ...                  ...           ...       ...
# 499995  499995                        10072395382         2
# 499996  499996                       571709661031         4
# 499997  499997                         4541459979         2
# 499998  499998  RzSDsyH@hotmail.com   98947185431         1
# 499999  499999                       880053388839         0
#
#                           OrderId
# 0
# 1       vDDJJcxfLtSfkooPhbYnJdxov
# 2
# 3       bHquEnCbbsGLqllwryxPsNOxa
# 4
# ...                           ...
# 499995  whJlUOGNqjxCRzmIRdURQvlNv
# 499996  JqIXOONvrwvJxZqNxCYHqnrKS
# 499997  beXCZSzcHaBwAYoDcpQqjuAFO
# 499998  ehjeFACGiwrERQxbziMxwOWku
# 499999  JibSBRgzYdfzkzbTuGUXrcvDX
#
# [500000 rows x 5 columns]

# %% [markdown]
# ## Data Cleaning
# Data cleaning is the mandatory step before any modeling.
# We append "Email_ " , "Phone_" and "OrderId_"  to help us identify the data type later on.

# %%
df.Email = df.Email.apply(lambda x: "Email_"+x if x !='' else '')
df.Phone = df.Phone.apply(lambda x: "Phone_"+x if x !='' else '')
df.OrderId = df.OrderId.apply(lambda x: "OrderId_"+x if x !='' else '')
df
# Out:
#             Id                      Email               Phone  Contacts  \
# 0            0       Email_gkzAbIy@qq.com                             1
# 1            1                             Phone_329442681752         4
# 2            2                               Phone_9125983679         0
# 3            3   Email_mdllpYmE@gmail.com                             0
# 4            4                                Phone_300364407         2
# ...        ...                        ...                 ...       ...
# 499995  499995                              Phone_10072395382         2
# 499996  499996                             Phone_571709661031         4
# 499997  499997                               Phone_4541459979         2
# 499998  499998  Email_RzSDsyH@hotmail.com   Phone_98947185431         1
# 499999  499999                             Phone_880053388839         0
#
#                                   OrderId
# 0
# 1       OrderId_vDDJJcxfLtSfkooPhbYnJdxov
# 2
# 3       OrderId_bHquEnCbbsGLqllwryxPsNOxa
# 4
# ...                                   ...
# 499995  OrderId_whJlUOGNqjxCRzmIRdURQvlNv
# 499996  OrderId_JqIXOONvrwvJxZqNxCYHqnrKS
# 499997  OrderId_beXCZSzcHaBwAYoDcpQqjuAFO
# 499998  OrderId_ehjeFACGiwrERQxbziMxwOWku
# 499999  OrderId_JibSBRgzYdfzkzbTuGUXrcvDX
#
# [500000 rows x 5 columns]

# %% [markdown]
# ## Creating the Graph network
# <b>1. Create the nodes with Id and with attributes as Contacts </b>

# %%
# Create the nodes with Id & Contacts

nodes = []

for _,Id,_,_,Contacts,_ in df.itertuples():
    nodes.append((Id,{"Contacts": Contacts}))

# %%
# Add the nodes into the new graph G

G = nx.Graph()
G.add_nodes_from(nodes)

# %%
# Now that we have 500000 nodes, 0 edges
G.number_of_nodes(), G.number_of_edges()
# Out:
# (500000, 0)

# %% [markdown]
# <b>2. Create the edges between: Id ↔ Email, Id ↔ Phone, Id ↔ OrderId</b>
#
# And the nodes of Email, Phone & OrderId are auto created in the process.

# %%
# Create the edges between: Id ↔ Email, Id ↔ Phone, Id ↔ OrderId

G.add_edges_from(df[df.Email != ''][['Id', 'Email']].to_records(index=False))
G.add_edges_from(df[df.Phone != ''][['Id', 'Phone']].to_records(index=False))
G.add_edges_from(df[df.OrderId != ''][['Id', 'OrderId']].to_records(index=False))

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (1129135, 837231)

# %% [markdown]
# <b>3. List down the connected component.</b>
#
# Each list contains 1 connected component

# %%
# List down the connected component

conn_comp = list(nx.connected_components(G))
conn_comp
# Out:
# [{0, 'Email_gkzAbIy@qq.com'},
#  {1,
#   115061,
#   140081,
#   165605,
#   2458,
#   476346,
#   98519,
#   'Email_JmMSyjzmxdelSmeAHBUi@yahoo.com',
#   'Email_ULziZaVD@hotmail.com',
#   'Email_WXJDcOYGapCzchhwH@gmail.com',
#   'Email_xXwrpkygOe@yahoo.com',
#   'OrderId_mwVhJZGKtahXEdLMwVLcOAxXG',
#   'OrderId_vDDJJcxfLtSfkooPhbYnJdxov',
#   'Phone_069988936',
#   'Phone_329442681752'},
#  {159312,
#   2,
#   322639,
#   348955,
#   'Email_EQnHOWbVizLZxRnm@gmail.com',
#   'OrderId_FTUBZYkUAEPIYmYvxtxKYYlqt',
#   'OrderId_zDhCFyaTJEqyxtEqiHxdTPmPt',
#   'Phone_5994952372',
#   'Phone_9125983679'},
#  {3, 'Email_mdllpYmE@gmail.com', 'OrderId_bHquEnCbbsGLqllwryxPsNOxa'},
#  {4, 'Phone_300364407'},
#  {212533,
#   215197,
#   226720,
#   383605,
#   404324,
#   458692,
#   482810,
#   5,
#   50,
#   'Email_TIMejlVYhfqjy@gmail.com',
#   'Email_izafiOnTIVibbz@hotmail.com',
#   'Email_yFcCGIfYcFKfmqpNk@yahoo.com',
#   'OrderId_XBkNrwcWWslDvSQdhYPfCpQJo',
#   'OrderId_sEgewZTtnDMAADcwLSjxsHiSK',
#   'Phone_04962058234',
#   'Phone_2529522887',
#   'Phone_840113148'},
#  {142067,
#   236367,
#   32871,
#   38,
#   6,
#   'Email_hESiBgYTxMnj@hotmail.com',
#   'Email_itOZKioDbLarhFmRm@hotmail.com',
#   'OrderId_ePEWcEEzOhZVwxhFlFEcWyyCg',
#   'OrderId_ngJuXgDuoMuNMpifSTHYmjvyP',
#   'OrderId_vOnbzMxsGvrAqsuPEekUYVpcM',
#   'Phone_207264189',
#   'Phone_6050341336'},
#  {7, 'Email_hqyunTiaXfIjhO@yahoo.com', 'OrderId_vxjYZtMUvNhtEBDruzQfjpsmX'},
#  {183160,
#   406623,
#   8,
#   'Email_XGUjcSiDpFKWEUCs@qq.com',
#   'Email_wIlKFhecSHyhzin@hotmail.com',
#   'OrderId_ShCZYWZXUFulRmKFqidfSAUBC',
#   'Phone_223604620644',
#   'Phone_958247811502'},
#  {13,
#   16708,
#   33415,
#   343161,
#   417916,
#   468927,
#   484896,
#   9,
#   'Email_WlDVDOEDEvSklXlVeW@gmail.com',
#   'Email_YsKhkKGJoQSNniHcr@yahoo.com',
#   'Email_baztAgq@gmail.com',
#   'Email_osIIQgAiZX@hotmail.com',
#   'OrderId_IqewrMXVTJqSsVklWFfOpdRNI',
#   'OrderId_eqsvnlUEEGbfPePNRQyZmNWQg',
#   'OrderId_lTFWCsPHyXciSbwCenwkNXOlv',
#   'OrderId_uZmSoONExsyEvZXwPAaRwTBzJ',
#   'Phone_562300766',
#   'Phone_6019130221'},
#  {10,
#   93270,
#   'OrderId_OHRFAXqbAzyxljoUDaOErwtrg',
#   'OrderId_rqtOUWxvivjfUnwhoISdpoESO',
#   'Phone_918973512631'},
#  {11, 244207, 'Email_QRamvop@qq.com'},
#  {12, 160893, 480595, 'Email_QexYMLXc@qq.com', 'Phone_188834273975'},
#  {14,
#   267520,
#   323910,
#   359095,
#   65749,
#   83313,
#   'Email_EpFjqcrumip@yahoo.com',
#   'Email_TFEFqCcFHnW@yahoo.com',
#   'Email_sXHosuHvxkP@gmail.com',
#   'OrderId_rbrdWpswvYIwIWIWOppvtluAK',
#   'OrderId_uwUOTlevAkzhnIqGgWHFsQKzO',
#   'Phone_17423803380',
#   'Phone_2802165027'},
#  {15,
#   17,
#   21197,
#   486106,
#   'Email_TNaMorNIWCJARsXlg@gmail.com',
#   'Email_woFJEIoVnrpZNO@qq.com',
#   'OrderId_GqpDeqZSwZTbPRrrGePkOhbSQ',
#   'OrderId_yfnHKQXeSqpIwkeKVurkWbQMf',
#   'Phone_092607900110',
#   'Phone_7987833980'},
#  {16, 'Phone_8888238873'},
#  {10380,
#   121268,
#   159329,
#   176080,
#   18,
#   235210,
#   261681,
#   26580,
#   274269,
#   327057,
#   382449,
#   415657,
#   450623,
#   70474,
#   70621,
#   79466,
#   'Email_JQfWDQWs@yahoo.com',
#   'Email_TpnGzfIuAzcV@hotmail.com',
#   'Email_WaPWOFB@qq.com',
#   'Email_pQLTiUynFTMQGlQvETVv@hotmail.com',
#   'Email_qOkuzhOuPsbltatw@qq.com',
#   'Email_sjoEThSNaVBlYk@gmail.com',
#   'Email_tndZkvBDwg@gmail.com',
#   'Email_tvmyxvORsIY@qq.com',
#   'OrderId_aIajZVepvBbvhqXHvbjqOFTfS',
#   'OrderId_fEyUsreJzZcMbpxgWUrGoXnfF',
#   'OrderId_gmhRChdMCpPyrlfyVYgRjZpCL',
#   'OrderId_oTFiidnLbXoQvioWJpamqiyoQ',
#   'OrderId_tlQLBeFOikNStmHCbBkblacgG',
#   'OrderId_vQXjSpqgUekYYuSeVOpdaPZme',
#   'OrderId_zSekjOkRLyiGjvOPikTKwksFK',
#   'Phone_222114312683',
#   'Phone_4717706173',
#   'Phone_481160062',
#   'Phone_66873440472',
#   'Phone_75690719591'},
#  {19, 406780, 'Email_OPDjDybln@qq.com', 'OrderId_hmEXuNUPZQyefHErmzjGbeeFK'},
#  {20, 'Email_pakhLVMLp@qq.com'},
#  {21,
#   499255,
#   'Email_BWoPWiRuMzWyInsDy@gmail.com',
#   'OrderId_MswKjQqGNxFUOgZyDtiksGKhJ',
#   'Phone_4379915223'},
#  {106701,
#   22,
#   231013,
#   269015,
#   298102,
#   408655,
#   416176,
#   453177,
#   4562,
#   473446,
#   'Email_FoaGWGbpnlvizkIG@qq.com',
#   'Email_KlzRMPbkvQBzWJqHcu@qq.com',
#   'Email_TyJUmykcLXzwPl@qq.com',
#   'OrderId_FAfkaPfbiYqJNLqonkuozigbW',
#   'OrderId_GrplYMCChyBJupkkQeUpOOENS',
#   'OrderId_XmUWArLmaqDKaYsdiumnfMLZK',
#   'OrderId_ejxhCiXsVEHPiOwwGPWjWOqYg',
#   'OrderId_qQKxmwmEBSCmIkVMQgFnPYDns',
#   'Phone_137993355',
#   'Phone_169540432039',
#   'Phone_3048747999',
#   'Phone_87750412055',
#   'Phone_92941405819'},
#  {192016,
#   1944,
#   23,
#   49506,
#   'Email_IbQQqQjz@gmail.com',
#   'Email_jsHBHNssMav@hotmail.com',
#   'OrderId_OnwHjZymfuCuiyVfqLzioMRKm',
#   'Phone_129827441',
#   'Phone_2306426482'},
#  {112670,
#   118722,
#   139764,
#   1485,
#   235060,
#   24,
#   278469,
#   386186,
#   412121,
#   'Email_hvHIobDGRaNAw@qq.com',
#   'Email_mJDLhbFcHYsq@qq.com',
#   'Email_wfqDWYYWNKJQlukecEUM@qq.com',
#   'OrderId_QYINulQPnmJIAgdbkCIlhVViS',
#   'OrderId_QpimNsrfVeVbCMIeriuSXGvqx',
#   'OrderId_ROSjJjyggGORZavdeLgijFQdk',
#   'OrderId_oHdrNrEdbtHJLHyxNbXlgqSMM',
#   'Phone_09488180270',
#   'Phone_8144347884'},
#  {25, 'Phone_8633026949'},
#  {229592,
#   26,
#   402598,
#   'OrderId_lIuGVCoYTcpMcQWyGusHFwJNF',
#   'Phone_387065011',
#   'Phone_687232848373'},
#  {112494,
#   158446,
#   237701,
#   246,
#   259786,
#   27,
#   41540,
#   'Email_HnpNQFirm@yahoo.com',
#   'Email_IfuJWjusJTr@qq.com',
#   'Email_IuOYhCmfTTIGu@yahoo.com',
#   'OrderId_JiXywPhlVNYUeUtzyzRcAuqdI',
#   'OrderId_OfxNOxjZKcGULQaJfzsDnWqsM',
#   'OrderId_qkvEQCgYjelKFtaNEwpVVvGPs',
#   'Phone_242005711663',
#   'Phone_289339351643',
#   'Phone_54969101720',
#   'Phone_720277528',
#   'Phone_73548392967',
#   'Phone_972226904152'},
#  {1271,
#   177136,
#   26068,
#   271446,
#   28,
#   382292,
#   487899,
#   495579,
#   'Email_ESHxYnDyJg@yahoo.com',
#   'Email_MbjTCmxpcqf@yahoo.com',
#   'Email_dwgaHwUMpbMSItcs@yahoo.com',
#   'Email_nkOLkwT@gmail.com',
#   'OrderId_nfVgFexPZGijuRCTKQOCRYKBe',
#   'Phone_028044435230',
#   'Phone_283604540933',
#   'Phone_399515218756',
#   'Phone_695751273481'},
#  {29,
#   364569,
#   437861,
#   463960,
#   64140,
#   'Email_QeUmxugpDKAKeRLNjX@yahoo.com',
#   'Email_dODFWRQk@yahoo.com',
#   'OrderId_bEUTzcgjaUOFbhtwnrrNAZTKN',
#   'OrderId_gBcAhbLWCASgJsOVYWJknHech',
#   'Phone_039615282001'},
#  {19563,
#   30,
#   'Email_mgKGRKoFOdsB@yahoo.com',
#   'OrderId_krTjhUVfqiDZCGFaQpJpQlYBs'},
#  {31,
#   66232,
#   'Email_JgfXOEbsOFW@yahoo.com',
#   'Email_LrDMxWTpx@qq.com',
#   'OrderId_evwWHyzhuIITmCuhioiIhsFtE'},
#  {32, 'Phone_38969610017'},
#  {117352,
#   269224,
#   33,
#   459,
#   46643,
#   499013,
#   'Email_AapUeVZEmikwXrThUncp@hotmail.com',
#   'Email_XLAVlZUqxWprVG@gmail.com',
#   'Email_hCzxVKHvKB@yahoo.com',
#   'Email_xaeXpbCVX@hotmail.com',
#   'OrderId_IWFKFTijQDxXGyWSrMwzbIOBI',
#   'OrderId_VFfXBTpVBgmCPBNSXsnckcwMM',
#   'OrderId_mFRWUrCVkmgYQpzCklCprmLSU',
#   'Phone_40846711002',
#   'Phone_721136055'},
#  {34, 'Phone_306249213'},
#  {35,
#   51,
#   'Email_LEQvQVjRnZGUzzii@qq.com',
#   'OrderId_tNyZAarWISkKcyhLPjYOVXfrD',
#   'Phone_677071683'},
#  {36, 'Email_YPuAqGfmVcEgE@gmail.com', 'OrderId_cbxcuGVlsFcpDwyhzIVgkPhrr'},
#  {1864,
#   37,
#   'Email_EpilxCxfqaTmksA@gmail.com',
#   'OrderId_viyXTQjuASUijgVgEYPCMMoeS',
#   'Phone_18095204655',
#   'Phone_2469790597'},
#  {110030,
#   122105,
#   191174,
#   20375,
#   23729,
#   254425,
#   262931,
#   285406,
#   32596,
#   346215,
#   354020,
#   364596,
#   39,
#   39187,
#   461467,
#   475371,
#   47554,
#   95806,
#   'Email_BGvoQpRwaVzjCxRfLGJz@yahoo.com',
#   'Email_LwAiwwoAjE@hotmail.com',
#   'Email_MCmNOxTOpsjbUYleGv@gmail.com',
#   'Email_PsVlemLYj@qq.com',
#   'Email_RzoQrfSEa@gmail.com',
#   'Email_YHuIOTlskuIGUJzuWAP@hotmail.com',
#   'Email_giSXngnLxmkMYgr@qq.com',
#   'Email_ihrIMgUfvnbZ@yahoo.com',
#   'Email_vRZzlelyt@hotmail.com',
#   'OrderId_GMDEKnkTYwKBAlqyZAUulieqW',
#   'OrderId_IFNEekKDYnDgthCOfYZVynYpy',
#   'OrderId_WIIInRcrFEEJRanlKIRdWKQxN',
#   'OrderId_kLSmIhgtuiuoKKkGlaQaksbvN',
#   'OrderId_ufMmeWdKoAKbbGRhfHEJkYmaw',
#   'Phone_159784246',
#   'Phone_353500003',
#   'Phone_4471336355',
#   'Phone_87567543045',
#   'Phone_993555347873'},
#  {1182,
#   170845,
#   171331,
#   185008,
#   196535,
#   198449,
#   208205,
#   217500,
#   239282,
#   256779,
#   264186,
#   283948,
#   28643,
#   296482,
#   311837,
#   313529,
#   339743,
#   373119,
#   389380,
#   395664,
#   396104,
#   40,
#   419260,
#   431243,
#   454084,
#   484815,
#   491223,
#   499570,
#   'Email_AGhWPOHFROLDKE@qq.com',
#   'Email_CwCzVQTymfwuQeGruDh@yahoo.com',
#   'Email_GGSPNDjXUUHiDLbZ@gmail.com',
#   'Email_KhEkbaQvtyhQAsYZ@gmail.com',
#   'Email_hKmbARrZtQkdzx@qq.com',
#   'Email_kdPxcXAyP@hotmail.com',
#   'Email_mnCqgyZpXZGUrEVkc@yahoo.com',
#   'Email_pIXrqTANSePl@qq.com',
#   'Email_tHyTKcKjxUBYt@yahoo.com',
#   'Email_vucBLNqaJUDgUsjlzsOO@yahoo.com',
#   'OrderId_EQJqbxvlnzSlrkAquyNNsWygq',
#   'OrderId_GSENHBvAtepWPzZAOcAuXvIIi',
#   'OrderId_PoxJIpkzVjuWolgMDOymFlpbM',
#   'OrderId_UUNchncGZHMmyDeZVdEvUBkEV',
#   'OrderId_ePDryGUameyEvHIPTQmgwUREm',
#   'OrderId_eXNGOIVLyXdJrygzyzWTrvZqZ',
#   'OrderId_fPmexEjBoMKGyJQEhMNBlBzui',
#   'OrderId_ivKrxGDlgGEoNyrDUBYRWCudZ',
#   'OrderId_qkcLpOMRftWGTbVbpLgKCOxlZ',
#   'OrderId_wbZibqtpNXojzhudvTDVKrRdK',
#   'OrderId_wrfYnTKAREJSNLyOHDcyHRsst',
#   'OrderId_zvKApvSPpXcxsaEjdmpxXVOaK',
#   'Phone_00557512592',
#   'Phone_02605587622',
#   'Phone_083721641',
#   'Phone_2551262884',
#   'Phone_446785146222',
#   'Phone_536774736',
#   'Phone_6608687302',
#   'Phone_8100026116',
#   'Phone_829468103121',
#   'Phone_89418671630',
#   'Phone_9273560689',
#   'Phone_976180725'},
#  {11667,
#   168137,
#   275580,
#   337549,
#   366951,
#   41,
#   64947,
#   'Email_RblfJMkJd@gmail.com',
#   'Email_XSArpmt@hotmail.com',
#   'Email_oYmDmDNUxhle@qq.com',
#   'Email_rKNcHWwUKYb@qq.com',
#   'OrderId_MkAMDUDNmDYVxlVGQHdxibMbj',
#   'OrderId_QdfzKgfIMWrRGqKBTXuQEYWwA',
#   'OrderId_UpGlTHwKvHwDfAIUVvFqQvhAH',
#   'OrderId_XfXgaWLmcCakaJqjPKFUtqjKD',
#   'Phone_046978944664',
#   'Phone_08599416810'},
#  {164913,
#   42,
#   'Email_VbaKKxkCzo@yahoo.com',
#   'OrderId_TsBwFmhSCeauMjfoMVkhTBdYI',
#   'Phone_315194406'},
#  {286788,
#   43,
#   480546,
#   'Email_PuIcTeGkVFuN@gmail.com',
#   'OrderId_wrGRiVjrpcVMGSDNwsMDFrRBt',
#   'Phone_38571967592',
#   'Phone_8730463856'},
#  {171746,
#   44,
#   'Email_rkxfmOdDeriajmcZGT@qq.com',
#   'OrderId_OYljrsEovjluhXHZrjruIGIvj'},
#  {45, 'OrderId_sHlgpJXxmsaJPuqzSMNyqKgpk', 'Phone_9416520356'},
#  {46, 'Email_FivCkMqgnZ@gmail.com'},
#  {47, 'Email_DEkFDIFBKSi@gmail.com', 'OrderId_NxuimjmpxXubFRJVyDMxeEbjT'},
#  {48, 'Email_VfuhRFLQevQ@yahoo.com'},
#  {179281, 49, 50840, 'Email_GNMmyGiWbSsDTdMayomQ@qq.com'},
#  {114882,
#   157219,
#   340482,
#   394326,
#   46079,
#   52,
#   'Email_ITSENNNBYRhq@yahoo.com',
#   'Email_WgixVLhGtyFxnQFY@hotmail.com',
#   'OrderId_IKZOVsmIGuWkRizFVlBEFEKBO',
#   'OrderId_JsORSKHmzWlRvSNKUTVofoPkZ',
#   'OrderId_oFILBFivHBcyGjtPCHUnHWfcJ',
#   'Phone_0539510998',
#   'Phone_4692439400'},
#  {53, 'Email_jHkRilpCWry@hotmail.com'},
#  {378247,
#   54,
#   'Email_CaqZJdaXw@gmail.com',
#   'OrderId_TmoVtgGCoHtVtSdXbnDToWJXq',
#   'Phone_80168501007'},
#  {55, 'Email_wwffNSus@hotmail.com'},
#  {56, 'Phone_5347826861'},
#  {111925,
#   131269,
#   1534,
#   174248,
#   264710,
#   298303,
#   34572,
#   386483,
#   393869,
#   40050,
#   418805,
#   460716,
#   472554,
#   57,
#   66405,
#   'Email_EBUmlJzrU@qq.com',
#   'Email_FIXlZrknjxTUHybp@hotmail.com',
#   'Email_SxpFINjL@yahoo.com',
#   'Email_TfWokarzZL@gmail.com',
#   'Email_ephPlgkEK@yahoo.com',
#   'Email_hnFziqBzgrVAknrZK@yahoo.com',
#   'Email_vemscjvUJahFaH@yahoo.com',
#   'OrderId_OZGNmVWkLvRWIWyOkENVMhOfU',
#   'OrderId_XtYxzIcyKneROGuAGaeIhgjom',
#   'OrderId_YKEmeqPCIaFeyjeeiHszbFSpE',
#   'OrderId_dqeIiAevxApkrtEiAtehhxxhq',
#   'OrderId_ehVwUbFPaMjFilNqRPIkcbFfh',
#   'OrderId_pctZmlWRXxhtJIkuhsaSywbyS',
#   'OrderId_vRFYytSytpeSOoVNlhdtsBztE',
#   'OrderId_wkFfwbHCwvYKgLcFgdeQxcUBu',
#   'Phone_143994642538',
#   'Phone_17297727203',
#   'Phone_3581014578',
#   'Phone_358326332312',
#   'Phone_871720188'},
#  {58, 'Email_vbzvuntiUfBVyjQOyH@yahoo.com'},
#  {59, 'Email_htOuIDNDyjaqBnBeJ@hotmail.com'},
#  {13981,
#   331792,
#   426590,
#   486286,
#   60,
#   7964,
#   'Email_imFjDAffVBweKEU@gmail.com',
#   'Email_uPnBRwvRT@qq.com',
#   'OrderId_MmiFeSqdjeXWtbtsfoEtdOTmn',
#   'OrderId_tWmROlbtumfRPYnhwhLNqMPQj',
#   'Phone_19916178730',
#   'Phone_3315269846'},
#  {61, 'Email_bMuPrDUjzxOGVTP@yahoo.com'},
#  {230246,
#   25476,
#   298529,
#   375889,
#   379246,
#   481395,
#   62,
#   92496,
#   9506,
#   'Email_AvtPdRAiSTzXH@hotmail.com',
#   'Email_GWLijhsvUv@gmail.com',
#   'Email_cnluKmgwZIvsgp@qq.com',
#   'OrderId_NuYyztuoluDdalKRccrrFOEmP',
#   'OrderId_fJawVHNxJSgXogqtSEZrCPqmQ',
#   'OrderId_vyRJXqtSJqbmEjcyELesbwRDm',
#   'OrderId_xGLRnVVxarDgViSkzrmBiFAqg',
#   'Phone_157404533'},
#  {241115,
#   471199,
#   63,
#   'Email_BEZucXyfs@gmail.com',
#   'Email_qfBZnXNs@yahoo.com',
#   'OrderId_tHxRHhDzmLGcybMwMUSdbmpwM',
#   'Phone_48864857029'},
#  {64, 'Email_HEeyfpYPe@yahoo.com', 'OrderId_lOPoVlAtsyNluMXxyzwyCRWLB'},
#  {114641,
#   169915,
#   206935,
#   357273,
#   65,
#   'Email_oYdtzWJsrUoz@gmail.com',
#   'Email_sFUHgCtQcYb@gmail.com',
#   'OrderId_ThUsmBZnxbgYjqcotEoCFFoFv',
#   'OrderId_hckSovHyBlJaoWQMYpPsVLPiC',
#   'Phone_07659080891',
#   'Phone_793551728'},
#  {66, 'Phone_5506092816'},
#  {111438,
#   145889,
#   1576,
#   190601,
#   284496,
#   439322,
#   461215,
#   67,
#   'Email_MtpiZAjJuV@gmail.com',
#   'Email_fUQuQmwiwzGtOAu@gmail.com',
#   'Email_pSeBotldQoQUG@hotmail.com',
#   'OrderId_DsQTgMdsTynskNJkHftVwJxbT',
#   'OrderId_HKyGyTxHdfPPPcJvocRJzuTVm',
#   'OrderId_NPYXpZnlwjvhkmLsUjKBeUIpX',
#   'OrderId_kjzOhlQoUudOzHfXxAnUWQAsH',
#   'Phone_5501158552',
#   'Phone_61020836616',
#   'Phone_931354063798'},
#  {1321,
#   187301,
#   321667,
#   68,
#   'Email_MqeWqLfAIPvgaelFet@hotmail.com',
#   'Email_xzVAaxzszbPsiWuVDeB@gmail.com',
#   'OrderId_MdrMYgcYixZsbYuNvFdmLyyeK',
#   'OrderId_pEMboRyVGIyVoMhRDsoaVbWLC',
#   'OrderId_yszJKOtWYrnjJoMPmXQMuZhiu',
#   'Phone_173754467363'},
#  {214159, 69, 'Email_YfRusUcquQn@qq.com', 'OrderId_vWfnhGjjHbGvGJhplkiAsqUXi'},
#  {70, 'Email_noZoUAotpAgkvXZhDPd@hotmail.com'},
#  {10088,
#   110495,
#   125054,
#   145501,
#   152973,
#   169975,
#   171236,
#   181647,
#   213907,
#   23134,
#   232849,
#   238913,
#   2441,
#   251219,
#   263203,
#   266190,
#   301846,
#   335,
#   3783,
#   382923,
#   397815,
#   459512,
#   478605,
#   48539,
#   63028,
#   71,
#   87600,
#   'Email_BBaloeSvnQxXGnouNx@yahoo.com',
#   'Email_HcXRQTpaZKryeub@yahoo.com',
#   'Email_KQbUURfnWhXlm@hotmail.com',
#   'Email_KcrrAxEGzwWRUPp@yahoo.com',
#   'Email_NwQsSALexeFz@qq.com',
#   'Email_UPyybPGrkzfKf@gmail.com',
#   'Email_ZUAGRxDrEdUuPSkfGvW@hotmail.com',
#   'Email_hcbgaPVCgOSkrpPrGWTP@hotmail.com',
#   'Email_hifUPVbrLlrkeoWtesi@hotmail.com',
#   'Email_kwktzZxdobUJKEsj@hotmail.com',
#   'Email_sjoAimXRBnBMqkBvE@gmail.com',
#   'Email_uDekWuhbk@hotmail.com',
#   'Email_vZdjxzrglvMrVNrSZz@yahoo.com',
#   'Email_xTBcIpf@yahoo.com',
#   'Email_yloLMrbobFphNgX@hotmail.com',
#   'OrderId_DFawbVpLUxwTQnxxAWbcyhFCB',
#   'OrderId_NzQPFeDZyUPHghjjANkoDUKdV',
#   'OrderId_ODkHSgKjLMOAYvzQuzdqQDzZa',
#   'OrderId_SRGItXVLNSePWrredzFhloXQs',
#   'OrderId_TiRAShJUgUzfreFOhTlqPqJBX',
#   'OrderId_cWQHerRwFgdiCIFLgSbCOztFm',
#   'OrderId_isUifsgawzwPMwXpRwmemJsov',
#   'OrderId_oTGxwQZHbIZbSnSasluyTYWWX',
#   'Phone_0007754742',
#   'Phone_09844494506',
#   'Phone_10121513276',
#   'Phone_1606928077',
#   'Phone_299297252',
#   'Phone_312571913',
#   'Phone_32976139281',
#   'Phone_49025423779',
#   'Phone_5742034092',
#   'Phone_896765208',
#   'Phone_93517595727'},
#  {414959, 72, 'Phone_874115701324'},
#  {73, 'Email_PPeJdqDqBrdQ@qq.com', 'OrderId_ZMofCUqTzvilxGCWpWQnZdnuo'},
#  {146498,
#   280238,
#   332989,
#   434328,
#   491356,
#   74,
#   74819,
#   'Email_bWLwANRjbfEbsgmjjCxO@gmail.com',
#   'Email_wWqwEUJRmISPH@yahoo.com',
#   'OrderId_NQAJIMLldKAyYHhKekoUoJpCL',
#   'OrderId_pSySsJoukEYxCJQeSVXgIDFlC',
#   'OrderId_vFJusnwXgKWtoWaLJdqwgFwxk',
#   'Phone_106204694',
#   'Phone_1353341719',
#   'Phone_160202795123',
#   'Phone_6526341535'},
#  {366910, 75, 'Email_rZVxQTVljQOROKag@gmail.com', 'Phone_18347336757'},
#  {470100,
#   76,
#   'Email_nxlcmJeQFps@yahoo.com',
#   'Email_oqSiHNjVBSsPONWP@gmail.com',
#   'OrderId_AAtjOQdHryvhlAOKCykFvTgKw'},
#  {77, 'Email_RTfrrHNi@hotmail.com'},
#  {199488,
#   266731,
#   285621,
#   468556,
#   78,
#   'Email_PeNqfqZJdmwGGOmamDv@yahoo.com',
#   'Email_YGCyitT@qq.com',
#   'OrderId_MbVdpVArCxHPZqMqhHSJAGTxb',
#   'OrderId_mCfoseoDRHyrwHQlGOcDwnRPp'},
#  {151123, 79, 'Phone_7078845898'},
#  {122330,
#   136069,
#   138219,
#   138888,
#   140452,
#   159022,
#   195334,
#   265667,
#   296648,
#   301815,
#   370204,
#   372153,
#   38705,
#   389680,
#   39843,
#   410682,
#   416731,
#   80,
#   'Email_CjaDSLGXpe@qq.com',
#   'Email_FuEwbJyWTsI@yahoo.com',
#   'Email_QMzINsco@gmail.com',
#   'Email_mydsYsnkqJyOENTatFD@gmail.com',
#   'Email_oZCptvRor@qq.com',
#   'OrderId_GsEmzrjrQwknBHYHPOfMGhliX',
#   'OrderId_SASyucmWPqNexynNowxKSsqhS',
#   'OrderId_awMkvsrcUfFLclZtFPmnrdGvI',
#   'OrderId_oPnBODMtSTuQHTXDUTgbJNTTL',
#   'OrderId_oRwwvILCHvnFnOslPrUMJxpZg',
#   'OrderId_phMBGPvCUabPAkNctcjGwGxkQ',
#   'OrderId_trOKKnsOKfztwsQhMZXmGpryg',
#   'OrderId_vgvcJKBPdXJafmpaRwwOrAhNJ',
#   'OrderId_wKlxqoeiaHjgRLmksXWJIVhZP',
#   'Phone_017927498',
#   'Phone_235322544',
#   'Phone_30110242087',
#   'Phone_303297057',
#   'Phone_35555731089',
#   'Phone_815809025',
#   'Phone_8849113339'},
#  {151818,
#   383073,
#   81,
#   'Email_iwgkwsLG@qq.com',
#   'OrderId_pMqGgaqWWHfpJNHBNNCprReja',
#   'OrderId_rgndaygEDvaMecsPQXtGvDLHb'},
#  {279875, 82, 'OrderId_GBHHRuXwAFQKjSZnfiEWflock', 'Phone_2905688150'},
#  {126500,
#   153101,
#   175025,
#   192415,
#   202951,
#   204437,
#   22387,
#   235552,
#   24340,
#   266341,
#   292695,
#   302668,
#   354979,
#   393915,
#   39776,
#   47463,
#   54994,
#   83,
#   'Email_FbTeppX@hotmail.com',
#   'Email_MIrpKoXtvGIeNiwYnPhi@gmail.com',
#   'Email_igDCTvExPN@hotmail.com',
#   'Email_imSMbnYHVg@hotmail.com',
#   'Email_nGuJELiWlJQPhaj@yahoo.com',
#   'OrderId_SWDfseWtgNHVruHSMJmobkWIK',
#   'OrderId_biKBBLTGIqVMSAmHXnoSwNwXw',
#   'OrderId_iuxpYzESXiqnLvHKuMQBPLtdO',
#   'OrderId_lrPKRLRhlKgsqqeprjdRfaMqz',
#   'OrderId_tKCJUnGkItKynDWYygcdrqBEZ',
#   'OrderId_xmgBUpUELuSQQUFqkiEexXzSW',
#   'Phone_16455902659',
#   'Phone_18087782746',
#   'Phone_33131736758',
#   'Phone_50836521346',
#   'Phone_509940201',
#   'Phone_517796468',
#   'Phone_6881604875',
#   'Phone_76780423457'},
#  {84, 'OrderId_gsxEodTBoBPzAMpcCIqdHdwSl', 'Phone_200902397'},
#  {271911, 85, 'Email_wTOhxRyyrVDXnmCBb@qq.com', 'Phone_350299140'},
#  {247375,
#   354315,
#   447444,
#   86,
#   'Email_QuIdiMhSGvlFiDSH@gmail.com',
#   'Email_umGFxXYHPMUKnX@qq.com',
#   'OrderId_EDSUnUBWkKymzjXqZwnlGhOxx',
#   'OrderId_ZrDmgxeNyKGkVoZrhdekNgXMj'},
#  {87, 'OrderId_jYftgwmvuVaArUKdBsrGDLAsu', 'Phone_148015042798'},
#  {88, 'Phone_734008642556'},
#  {316049,
#   470531,
#   89,
#   'Email_bKowchirEVTRGNJdaDj@yahoo.com',
#   'Email_zUbQLByvDEWHgHYmavoD@yahoo.com',
#   'OrderId_NHUVbfqPcrAcgHytKuZIPovrI',
#   'OrderId_YhPVmtjLDkwiIhmimtfohNakR',
#   'Phone_18146382448'},
#  {272530,
#   462213,
#   53830,
#   90,
#   'Email_LaclGMEesnBzmUWDbZ@qq.com',
#   'Email_pIbTzsAXMUZVJtAd@qq.com',
#   'OrderId_ZYqwBRhihKQcrDipXWxQfiWHy',
#   'OrderId_jiVTGxJBOwFCJuHltuAKEXprZ'},
#  {101634,
#   11428,
#   154339,
#   155324,
#   160152,
#   163969,
#   177073,
#   189307,
#   201173,
#   207738,
#   212878,
#   219245,
#   224737,
#   228267,
#   238605,
#   305637,
#   331943,
#   332912,
#   353023,
#   356675,
#   361432,
#   377255,
#   378577,
#   391918,
#   413237,
#   446819,
#   46544,
#   60777,
#   62822,
#   77764,
#   82757,
#   91,
#   97152,
#   'Email_EJCCyOZ@gmail.com',
#   'Email_GMAfnAFVWNiHTSHF@hotmail.com',
#   'Email_HDNYqrCeTZYf@hotmail.com',
#   'Email_JSvWknzPbezpYqyvfSoL@yahoo.com',
#   'Email_OiwpMopPNTYnFNOL@qq.com',
#   'Email_PyQLvqUeQUqNIPNdz@hotmail.com',
#   'Email_bvTIIMuMBtv@gmail.com',
#   'Email_fGzdjcuicxE@hotmail.com',
#   'Email_fxWosYR@gmail.com',
#   'Email_rlqeEiLQV@qq.com',
#   'Email_urTfsDJ@qq.com',
#   'Email_zAPwSDrs@qq.com',
#   'OrderId_ADNxvSPuVozHavFIsOFwivaOi',
#   'OrderId_DjziZTvVjiSTDMUqsQoRjkmLU',
#   'OrderId_DmjQVZrryNyAIRHZzocuEWCXu',
#   'OrderId_GbKkxcGekjTxZJzMcfUGXauHK',
#   'OrderId_LnyHASmZBljIAozMIdbXeZmyM',
#   'OrderId_OiOJXQjHKCzNqIZnILJYesAmo',
#   'OrderId_fWpgqqvGMrMajDRSoUIHwlgMp',
#   'OrderId_faYOnSguJRjFAkVBFEpjyFowu',
#   'OrderId_hshcMAlImFybPJDHTAsQkafbk',
#   'OrderId_kUVANLWoxjtLhhFSMWelirWFj',
#   'OrderId_kimhsCzAQvejLBXLCuWWIyKqL',
#   'OrderId_kqxrQiWovjhRgkNhodInEwvup',
#   'OrderId_oRXVAiUsjethwOcJaOkotcMve',
#   'OrderId_zgknvjEpJbjWFtSvHJcIIKHjw',
#   'Phone_606128359',
#   'Phone_6317289014',
#   'Phone_728824726940',
#   'Phone_728974057045',
#   'Phone_75687603952',
#   'Phone_7594788198',
#   'Phone_793924973772',
#   'Phone_95089314321',
#   'Phone_9982072621'},
#  {287578,
#   51599,
#   81863,
#   92,
#   'Email_LiuUkvbtKUNyU@gmail.com',
#   'Email_aKTLQqM@qq.com',
#   'OrderId_OkYyHvYAKbLHStueWfwXYPQDi',
#   'OrderId_WFcWwnHwgXEYXyEnTwtJoTAYC',
#   'Phone_8703821080'},
#  {463050,
#   93,
#   'Email_QWTggRqRJqQ@yahoo.com',
#   'OrderId_DWsgZdUKEUBrzIMiHqYwRanyM',
#   'Phone_030637265'},
#  {198708,
#   223721,
#   225405,
#   264494,
#   269455,
#   279700,
#   423724,
#   478525,
#   497318,
#   94,
#   'Email_JtwUkKAko@qq.com',
#   'Email_VyduXCHlqRqTOTq@yahoo.com',
#   'Email_gSlhVKnQRmMyJddHF@qq.com',
#   'OrderId_dNcjUazvUfRlzXrQYoJOoQKfe',
#   'OrderId_ggikiosdakQPDVRVeUELhSbMT',
#   'OrderId_kgNhSyEXhbEaGYGfOjAvYVcwi',
#   'OrderId_tlbFkZgyOxWnYjbRtDKajhOnj',
#   'Phone_418749991856',
#   'Phone_99521897996'},
#  {95, 'Email_gWNVijaZJrQUSBhxHi@qq.com'},
#  {116460,
#   356800,
#   58319,
#   66706,
#   96,
#   9854,
#   'Email_LUXQhmKHSUeTA@gmail.com',
#   'Email_lupQIhzMPGkpp@gmail.com',
#   'Email_vXONbywHnGhLMppx@yahoo.com',
#   'OrderId_CVGixrrHHbvLmNAhamcnUQHrR',
#   'Phone_284422969379',
#   'Phone_46840061055',
#   'Phone_468981077',
#   'Phone_74283731763'},
#  {97, 'Email_FoDkCwaAyfreFvCqPcBC@yahoo.com'},
#  {98, 'Email_DxtVenmxYlNSRxG@qq.com'},
#  {115978,
#   127705,
#   62730,
#   99,
#   'Email_FAJUpQUScWAOq@qq.com',
#   'Email_QIQgMnLzDDgxxA@qq.com',
#   'Email_xwDopMZXPuxOhckeE@hotmail.com',
#   'OrderId_ABnnqCdsskYAdBiaoOIgpCwbo',
#   'Phone_554328484',
#   'Phone_99528395769'},
#  {100,
#   109959,
#   1157,
#   129043,
#   146402,
#   181117,
#   205684,
#   220328,
#   280716,
#   282502,
#   306045,
#   379958,
#   437044,
#   451994,
#   475973,
#   79530,
#   822,
#   95287,
#   'Email_KVJqkaaCFmoNXwysz@qq.com',
#   'Email_MJswrjxKwmqIwEO@yahoo.com',
#   'Email_OoyYvFjnK@gmail.com',
#   'Email_THYgCNSGLjY@hotmail.com',
#   'Email_UejyCoDR@hotmail.com',
#   'Email_ZPWPUtKtJHemEpEkfsT@yahoo.com',
#   'Email_gGEJWeoUReiIymvfW@qq.com',
#   'Email_qrzkgDTptgynahOSJsXV@yahoo.com',
#   'Email_uGgTIdvLqnPygKqRnKfu@yahoo.com',
#   'Email_uYoEwjnJOOlvSwDPOR@hotmail.com',
#   'Email_utpEbWabDUDpUZ@gmail.com',
#   'Email_xDsHlOboIWNpGMLp@hotmail.com',
#   'OrderId_CQOPxezJOIfZMxNxvQEyuLKrJ',
#   'OrderId_QPBAIxFMgIPGNItHyzLMmXwrG',
#   'OrderId_RKKKiOTjYrrtRjRqtjzxuMnag',
#   'OrderId_WpJsJnusArDzOgJYqwcTDKSPV',
#   'OrderId_iQbvLolduGMRuryTncAJZTCPk',
#   'OrderId_tUUhifgbRDhUcSyiPNEpzeVKj',
#   'Phone_0269893793',
#   'Phone_075673879',
#   'Phone_103975811',
#   'Phone_205927629'},
#  {101,
#   360820,
#   415852,
#   54178,
#   56651,
#   'Email_EhOWvLh@qq.com',
#   'Email_HisTPKHWU@gmail.com',
#   'Email_xOpoLXXOmwUMbkac@yahoo.com',
#   'OrderId_tPvFxPHGwEZCGLpPxZFcEtfKk',
#   'Phone_83551083718'},
#  {102,
#   466297,
#   'Email_MNoemgOcEhVHYV@hotmail.com',
#   'OrderId_YRdXRJZbmohUDidiIcrgoFMQF',
#   'Phone_92168491286'},
#  {103,
#   26590,
#   2788,
#   298414,
#   336851,
#   337168,
#   429453,
#   'Email_lqUwMCS@gmail.com',
#   'Email_rAebgxybGBEDLsxa@hotmail.com',
#   'OrderId_JXQGKTzCPHhXXuEhnjksoTqqS',
#   'OrderId_TloLPPUolocTJtNGPWmtAYFLg',
#   'OrderId_wlOmFjeMrqJeAVlzgiyuqWZBe',
#   'Phone_01290170388',
#   'Phone_282774897',
#   'Phone_45833203281'},
#  {104, 'Phone_559057762'},
#  {105,
#   15905,
#   290943,
#   360283,
#   484596,
#   486426,
#   5597,
#   68965,
#   89832,
#   'Email_DPpBKHCemJyOYf@yahoo.com',
#   'Email_NmSApva@hotmail.com',
#   'Email_aooaVSm@yahoo.com',
#   'Email_ifDjIGHZNBFvos@qq.com',
#   'Email_pRPbhccnmiyjggBxGbDL@yahoo.com',
#   'Email_twyOovxU@yahoo.com',
#   'OrderId_KJowqQPYTFxlTbJzInXmRsWlG',
#   'OrderId_gKsGhzFkwZtCafNfHKCBViYoK',
#   'OrderId_ypYkvNPjmtmXMnxYVfNBIRvNc',
#   'Phone_094810134',
#   'Phone_1234569106',
#   'Phone_173337426101'},
#  {106,
#   164892,
#   298789,
#   478387,
#   494415,
#   856,
#   'Email_PWlJEmM@qq.com',
#   'Email_fivpUkKmzHsXUciOXel@hotmail.com',
#   'Email_skJSOOfoBoTwOetvDNnX@hotmail.com',
#   'OrderId_iNgGEquGzAAeuUnTOrGjoftJu',
#   'Phone_022355547845',
#   'Phone_24488963028',
#   'Phone_84100491512'},
#  {107,
#   178290,
#   280212,
#   316970,
#   465,
#   'Email_AmpQmALNXXZdcvhexg@hotmail.com',
#   'Email_AuPxmmIJsoDifFziZnmf@hotmail.com',
#   'Email_rFaXtQLBoS@yahoo.com',
#   'OrderId_EWJQqqYwexPBOrBfHoKhFKQNC',
#   'OrderId_MUHIilLdhoAyeaNKjlmwwLKkB',
#   'Phone_153165984012',
#   'Phone_7213414557',
#   'Phone_95941865123'},
#  {108,
#   109593,
#   181236,
#   470335,
#   68001,
#   87503,
#   97890,
#   'Email_flfdxdFxoHNNq@yahoo.com',
#   'Email_wNcyjZdZJMIOZv@qq.com',
#   'OrderId_TqeDbCBMbXDbBcIZIdfcliUMs',
#   'Phone_285729047',
#   'Phone_2933420869',
#   'Phone_544503197516',
#   'Phone_715015995795'},
#  {109,
#   237280,
#   294,
#   'Email_ZmEEjyvpxf@gmail.com',
#   'Email_ckULfmuWRNSEE@gmail.com',
#   'OrderId_iqSSKRKJuXKNTKCUPwTrencOp',
#   'OrderId_rIQjUyauvUMJNreLqtFSiFnWX',
#   'Phone_67297509936'},
#  {110,
#   157993,
#   429244,
#   460054,
#   60486,
#   63603,
#   'Email_BXNWmZnhhFPSL@yahoo.com',
#   'Email_FEsjvfj@hotmail.com',
#   'Email_FTiwvgVxht@hotmail.com',
#   'Email_HolrRJzwPJEKvgMCQiq@gmail.com',
#   'OrderId_SaORUvaxsHVQWizOJoZDQODxZ',
#   'OrderId_pLALzTpktLJLJPNCalVSiruAi',
#   'Phone_92496398235'},
#  {111, 'Email_gybeZHPxueSv@qq.com'},
#  {112,
#   135,
#   182934,
#   188141,
#   240831,
#   289600,
#   397798,
#   429441,
#   456371,
#   463263,
#   467248,
#   65778,
#   'Email_JUNsiVxJajykEjkh@yahoo.com',
#   'Email_OoydLhjAkibawUP@yahoo.com',
#   'Email_PUBeQAucSMjk@qq.com',
#   'Email_RRSYlbyTBdJrD@hotmail.com',
#   'Email_wrOPTRerFQxaXqYweYI@hotmail.com',
#   'Email_xpyvnnuq@hotmail.com',
#   'OrderId_PNvByRxSAaCxarBTYeyIfCQto',
#   'OrderId_ifGXOmJclEOFHEiWJuSOMbYOf',
#   'OrderId_sUIMdgrMfnrCbjhSmicqcbEDb',
#   'OrderId_tbyJoQXLzSCBRYgrLbmdEKEcy',
#   'Phone_190895419',
#   'Phone_3931623111',
#   'Phone_940933194650'},
#  {113,
#   409673,
#   413629,
#   'Email_weWbQSdLDmWfTUsEu@yahoo.com',
#   'OrderId_FmJHhLhvgpShnZagfEubsQcEQ'},
#  {114, 'Email_FbRvRZNidTEvJLcC@qq.com', 'OrderId_CIxdxXBuhGTlQenktWaYUFWeq'},
#  {115, 215373, 303417, 'Email_hbLLBmxsGjSlywFecLx@qq.com', 'Phone_518190064'},
#  {116,
#   17086,
#   19803,
#   221885,
#   275026,
#   292480,
#   301164,
#   302539,
#   30727,
#   365527,
#   366421,
#   379989,
#   384752,
#   388164,
#   415826,
#   471003,
#   478195,
#   48616,
#   494089,
#   498208,
#   75473,
#   95005,
#   'Email_BCBvAYlhgbOwGAxzjK@yahoo.com',
#   'Email_GBkYPLzdOZTSz@yahoo.com',
#   'Email_MysCtfC@hotmail.com',
#   'Email_VYAaWRMHAMyiqFpmItOu@yahoo.com',
#   'Email_WQwjdcaqQyGVSiLTP@hotmail.com',
#   'Email_bdwLEgiOuF@gmail.com',
#   'Email_cMWNSkwZrdUyEpBYSz@qq.com',
#   'Email_hBSjzviAvLFV@hotmail.com',
#   'Email_sjnUjywRbUdBQX@qq.com',
#   'Email_sysgVdXua@hotmail.com',
#   'Email_wLEhTaPzNOVnibLzdAYl@qq.com',
#   'OrderId_ILJzORYkDpKBzmbpKFxQQkpog',
#   'OrderId_IxFnRhTKsNHMYMLywXsrABVWe',
#   'OrderId_JWeswKeWdWYdpDRHTWZZyFpGD',
#   'OrderId_RymmeFzLJKOOFqDWbQCfgKzMY',
#   'OrderId_iZafHZccVuKNHWMOPSwFfxnsA',
#   'OrderId_jRRXXApgeJYRxFPKPdGyEWvdZ',
#   'OrderId_rdkBSJgGTkQOLaMdubFghhhJX',
#   'OrderId_zJbwoLMvsBbOyEBIJdPyxyKiZ',
#   'Phone_032626427',
#   'Phone_52513840013',
#   'Phone_5496995406',
#   'Phone_71957224898',
#   'Phone_732396741',
#   'Phone_7810092848',
#   'Phone_7828099882',
#   'Phone_8302655680'},
#  {117,
#   184856,
#   355948,
#   'Email_BzlEdUkrWXJDeNlTw@qq.com',
#   'Email_MaQpqvUbifOrKutPHYRW@yahoo.com',
#   'OrderId_AUtSBzztOpJAGuYAfkgzaUASn',
#   'OrderId_mNTiDtsaDwzTlHeBloOJBxzjk',
#   'Phone_38807140014'},
#  {118,
#   18056,
#   323184,
#   'Email_FDpfIBtmX@qq.com',
#   'OrderId_UiFckUjbalbHDFtWvqDfEUHPn',
#   'Phone_226820588627'},
#  {119,
#   177581,
#   301632,
#   437059,
#   83681,
#   'Email_BrAyuofchqgirmc@hotmail.com',
#   'Email_fwqGumUf@gmail.com',
#   'OrderId_JReropPdxOBzpChHZqJamGLWN',
#   'Phone_5603040530'},
#  {120, 'Phone_63714135356'},
#  {116467,
#   121,
#   12840,
#   23604,
#   465574,
#   68014,
#   'Email_HpwhZYvSBps@yahoo.com',
#   'Email_mQfXVxyakGwWI@yahoo.com',
#   'OrderId_QbnYRhFJhHZgirePhITCJkblD',
#   'OrderId_RvLoLiNYoVOqIYNSlROJwLSHB',
#   'OrderId_hHGzqFLfPSeuwOqKOTDvYsmYT',
#   'Phone_086474020',
#   'Phone_804120596401',
#   'Phone_89516449154'},
#  {122, 'Phone_938222315259'},
#  {123,
#   334454,
#   349627,
#   462949,
#   491626,
#   93061,
#   'Email_InngJtlnOsTvm@yahoo.com',
#   'Email_JhnWVtaBj@qq.com',
#   'Email_PQqXPtc@hotmail.com',
#   'OrderId_iwiiyxfSbOhZwyCzsXZkOxdds',
#   'OrderId_kuRDDfRofPhPrUzUbKYCDeGjD',
#   'Phone_422551110327'},
#  {124,
#   216113,
#   96409,
#   'Email_NzJdyVphUgWrqcaA@gmail.com',
#   'OrderId_WpXMBAWwfaZEaniOhVLlwoNne',
#   'OrderId_eePARxxhdXmaBpSzVARhtQjmG'},
#  {125, 'Email_BtHVHrl@hotmail.com'},
#  {126, 'Phone_1006161396'},
#  {127,
#   449222,
#   76310,
#   'Email_LELLffIusEvIsml@hotmail.com',
#   'OrderId_tUBxZSUIUOLwCBcSRgDmerHcI',
#   'Phone_306329565193'},
#  {128, 429492, 'Phone_85891768089'},
#  {106690,
#   121941,
#   129,
#   'Email_XGvcIWUvXTEVDReUK@gmail.com',
#   'OrderId_iSOMQDGbjeHQhflnYXvdkZDks',
#   'OrderId_yTmHdxmsavyBcurLOLzfNcuya',
#   'Phone_6350480573'},
#  {130, 'OrderId_bqjaiBFUSObCRqSOSYOzNerhS', 'Phone_220748086'},
#  {131,
#   222540,
#   366341,
#   39449,
#   400892,
#   481588,
#   492598,
#   'Email_YIYfpkEtzdfVF@qq.com',
#   'Email_bTFjEOJe@qq.com',
#   'Email_kTGjLBKBEDWybgkSfyew@qq.com',
#   'OrderId_JBAhWoAKyhFkGwAZZAMUSvOIf',
#   'OrderId_YclUEKtKDStbDRJgNjDIQTvhh',
#   'OrderId_zenSLlNlFkyQWdnkqkdvtyYGz',
#   'Phone_054357284127',
#   'Phone_3354736600'},
#  {127193,
#   132,
#   137580,
#   14271,
#   156051,
#   162374,
#   166962,
#   170043,
#   181603,
#   187111,
#   217593,
#   257791,
#   278357,
#   289324,
#   34614,
#   349079,
#   367644,
#   369744,
#   453735,
#   468043,
#   'Email_DzqXzMqCfwdZuBwnn@qq.com',
#   'Email_GrVJIQGMiJmad@yahoo.com',
#   'Email_SCeoIQbtbPRcypJMXffQ@yahoo.com',
#   'Email_SSPFPbSTIcXqIPM@gmail.com',
#   'Email_ZNQTXrn@gmail.com',
#   'Email_xDCIWwFkhWSCx@yahoo.com',
#   'OrderId_SnlcFQydcREDqwkTHidnbcJlA',
#   'OrderId_UMVjEtTKUjBXmpYsqFuLeyiXQ',
#   'OrderId_WpdVbaMDppLFKrZGQZLFpYfhA',
#   'OrderId_rTTVLoheDSBWJnbxVsPJXvaej',
#   'OrderId_rcesqtiZHPDddUaQhSleaIqqq',
#   'OrderId_wpvMAyZcxjCEgXzKweFoAmOIZ',
#   'Phone_1089229347',
#   'Phone_129920593',
#   'Phone_2892428098',
#   'Phone_316046010',
#   'Phone_5220100969',
#   'Phone_59200037543',
#   'Phone_701710717',
#   'Phone_857205701901'},
#  {133,
#   445333,
#   97036,
#   'Email_ABqRBkQmApxRYwueSFot@qq.com',
#   'Email_HFszcpKcuWQ@qq.com',
#   'OrderId_eQzMNvWddGmmzekTdVlcNvCzi'},
#  {134, 'Phone_564566508'},
#  {108365,
#   136,
#   473933,
#   69515,
#   'Email_BdShYGEXlY@hotmail.com',
#   'Phone_2941937332'},
#  {107753,
#   137,
#   'Email_WsKjvKQ@yahoo.com',
#   'OrderId_CzwJBGDlfVgbdEcTYWbxlSSQH',
#   'Phone_86879224830'},
#  {106827,
#   138,
#   188357,
#   216438,
#   241143,
#   281849,
#   389414,
#   428562,
#   'Email_NGTmxRzfoPgZHRJuwAfv@gmail.com',
#   'Email_euTuvdbiwiZAveBoxIAf@yahoo.com',
#   'Email_uCXBgcZdFW@qq.com',
#   'OrderId_EDXslCmneEZywlpejGzwEZKxr',
#   'OrderId_aedAmLmmCvNZURUgkNhWcYVBH',
#   'OrderId_fUevnlfejVLuXPbGMBvpfrzSB',
#   'Phone_650495650'},
#  {139, 'Email_PCzUnDZtxhw@qq.com', 'OrderId_OMmwNvzEhgUWfDbRLQNgPsGtE'},
#  {140, 304532, 'Email_HPwkVVK@gmail.com', 'Phone_1689908957'},
#  {141, 99896, 'OrderId_bXjRObQOlOsSIEpBdbIZrKfrA', 'Phone_052182543'},
#  {142, 'Phone_94116159570'},
#  {143, 'Email_CuzgfpQqXIbdanh@gmail.com', 'OrderId_eFKUqolXsiHWxoLqTPSUVsHpD'},
#  {144, 'Email_PqPsYoqcfh@hotmail.com'},
#  {145,
#   217781,
#   234084,
#   290087,
#   365222,
#   410226,
#   425856,
#   89646,
#   'Email_lHEWWERWsEDqFaqbMpv@yahoo.com',
#   'Email_lNaaNaJOkT@hotmail.com',
#   'OrderId_dRybFUHhtqBvOEPaEXEcECnAd',
#   'OrderId_kDRSvrDdZjbEsNbRScYzsdXja',
#   'Phone_27911477545',
#   'Phone_304011921',
#   'Phone_772788534'},
#  {146, 298152, 'Email_PyLLglCYbiArmXXmCmX@gmail.com'},
#  {147, 'Email_BKJjGtLPZxa@yahoo.com', 'OrderId_dFbHuzwViPnAFAnueMoCbZgST'},
#  {148,
#   271214,
#   286693,
#   303270,
#   33408,
#   81493,
#   'Email_SDMFSbKh@gmail.com',
#   'Email_kpXVrJOFmqtqFXfh@hotmail.com',
#   'OrderId_lLpwjleRBWiaPNcCZcyKIYIte',
#   'OrderId_nqXxJQUAMbghVJVMDLoinOGSy',
#   'OrderId_rWQwPBoUMhdqahKbtWcxIBdOz',
#   'Phone_765252921'},
#  {149, 30279, 'OrderId_OpHOFjgtCKdJBfYpcaUdTAtrh', 'Phone_3809604154'},
#  {150, 'Email_qsdUQUN@yahoo.com', 'OrderId_VyOGtbbLMGbeFgRNUHNbhRnvt'},
#  {151, 'Email_NraLHNlD@hotmail.com'},
#  {152, 359279, 'Phone_930458464795'},
#  {153, 76417, 'OrderId_icwuHXnOFmzbyUhPTDgBxrSFF', 'Phone_098345222736'},
#  {105122,
#   154,
#   'Email_sPaqCuzlchrc@hotmail.com',
#   'OrderId_lqEegwVAiSmepuzknPRowacMU',
#   'Phone_4566614194'},
#  {155,
#   485385,
#   81016,
#   'Email_XDmUsdeDKhHHgEaaUnMR@gmail.com',
#   'OrderId_fwpIzonxiWslZgUCPHWTFuPBT',
#   'Phone_361545073270',
#   'Phone_8181137036'},
#  {156, 'Phone_883170810'},
#  {157, 'Email_DHFNQVFQKkLHbI@gmail.com'},
#  {158,
#   313250,
#   'Email_LGludLmnhmTys@yahoo.com',
#   'OrderId_peVJMcNLpJvuFfNffROKncfVf',
#   'Phone_17652069936'},
#  {159, 'Email_ofuZDVfaKziajtg@yahoo.com'},
#  {160,
#   173595,
#   213755,
#   88820,
#   'Email_AehZpeLsfDwDslEB@gmail.com',
#   'Email_OOAZbdOVXukikQtjn@yahoo.com',
#   'Phone_1396079883'},
#  {10153,
#   161,
#   171974,
#   293201,
#   349911,
#   380974,
#   44305,
#   483377,
#   72835,
#   88731,
#   'Email_FKcdsbfOhasChZXNrklk@gmail.com',
#   'Email_NVLekvgdnvpKZKBr@yahoo.com',
#   'Email_mnGuZqYMqKJq@gmail.com',
#   'Email_vKmsWtZOdItwVmV@gmail.com',
#   'OrderId_ETFBgWmfevokVQVfNKBiASEnk',
#   'OrderId_EdKmtmGsUSUPoXbuFPsCseAfQ',
#   'OrderId_oEPYFFxbJRLglRigmwmTVxiSw',
#   'OrderId_ysLfNxRdZwBFoprezGGuXPdCZ',
#   'Phone_19621095250',
#   'Phone_83969889025'},
#  {162,
#   'Email_nhGyCFGUHIGmhSacZdt@gmail.com',
#   'OrderId_PBYDYAIbqhwnfwednJGLvyefV'},
#  {163,
#   280419,
#   405439,
#   79377,
#   'Email_mCkaAvktFcCPnxV@qq.com',
#   'Email_oBjIJAQ@gmail.com',
#   'OrderId_aeWLyPosUgwHPAwneyYltkHpX',
#   'OrderId_ceLUSNfqiokcQFvMjjPhZMpdi'},
#  {110666,
#   12101,
#   1259,
#   145523,
#   14883,
#   160154,
#   1610,
#   164,
#   282091,
#   411076,
#   477605,
#   56600,
#   57027,
#   76148,
#   937,
#   'Email_IFrTSapRPx@qq.com',
#   'Email_KYtGMZNIEnCRrT@yahoo.com',
#   'Email_RUPNOkfSMx@yahoo.com',
#   'Email_VJKRBTqWhhcWtTDhGUl@gmail.com',
#   'Email_cecivqrelho@hotmail.com',
#   'Email_iBWClQPXk@gmail.com',
#   'Email_iHxzHaBqDh@hotmail.com',
#   'Email_wQRwvNPoQGWvBJpFnKOi@qq.com',
#   'OrderId_CafSnbYwOUBXwENDgmpZsMsvw',
#   'OrderId_OhKzqUboXKQpoRsBvseekfTcj',
#   'OrderId_cZfvovcxDKJfvtAugkaBKVXNX',
#   'Phone_325893795795',
#   'Phone_509439833745',
#   'Phone_610752585',
#   'Phone_653331539309',
#   'Phone_787355023',
#   'Phone_9207813396'},
#  {165, 'Phone_8272754417'},
#  {166, 'Email_NYWUhaXYf@qq.com', 'OrderId_ESILGklpHmzmadxHYmjPfgrvp'},
#  {167, 'Phone_654303634128'},
#  {168,
#   209740,
#   386,
#   392461,
#   'Email_AcIknoOmY@gmail.com',
#   'Email_YEalfwd@gmail.com',
#   'Email_gMMunMRumqSHMf@yahoo.com',
#   'OrderId_KxuYQIOYSrfWFHHJWWpkChmfM',
#   'OrderId_huaTJCmUMLNraOBuauwXGJBjU',
#   'Phone_11381049522'},
#  {169, 'Email_RmXnjDrIhaLujavY@gmail.com'},
#  {170, 'Email_ploQPipacr@hotmail.com', 'OrderId_FAGDTXqjJWwyqJfEYbdjtkdsI'},
#  {163627,
#   171,
#   29356,
#   42724,
#   474980,
#   479996,
#   70858,
#   90425,
#   'Email_CWaCzNVPyeCZcb@gmail.com',
#   'Email_aJMyYrD@qq.com',
#   'Email_ymZDwFMPHjd@gmail.com',
#   'OrderId_RQlagjjjVxFwweMFJNpJpYoRR',
#   'OrderId_sZzuTIeEWVhSsfInsAAtIrMQJ',
#   'OrderId_yMrMYlmIvXozGCtmYNvDsqREb',
#   'Phone_53325313678',
#   'Phone_66364117947',
#   'Phone_99402756483'},
#  {172, 'Phone_2394063357'},
#  {133089,
#   173,
#   'Email_YSynIqAfYUtEzmB@qq.com',
#   'OrderId_QVVQXYXiKGtXkPInfdYAwGfuc'},
#  {174,
#   4484,
#   459442,
#   'OrderId_LjGNKdkIprMTrIbMNChdoGzEH',
#   'Phone_442152884110',
#   'Phone_804691906738'},
#  {175, 'Email_UWDzBbeHQHiY@gmail.com', 'OrderId_eUasmHqTrrzhNmhoXpPCXxmsS'},
#  {176,
#   304820,
#   311652,
#   'Email_IbmFDSTvFamghZyb@qq.com',
#   'Email_qPqGXCttcwfWvuXlXY@gmail.com',
#   'Phone_7552834161'},
#  {177, 483854, 'Email_hmapCeJfrhe@hotmail.com'},
#  {110829,
#   121708,
#   123015,
#   1299,
#   14178,
#   166455,
#   169144,
#   178,
#   183274,
#   190954,
#   1918,
#   198810,
#   203228,
#   224509,
#   242675,
#   268841,
#   300059,
#   323713,
#   338541,
#   342439,
#   342853,
#   363579,
#   384322,
#   397156,
#   398477,
#   399635,
#   40898,
#   428730,
#   473009,
#   480875,
#   73139,
#   74088,
#   90912,
#   9437,
#   'Email_LjxsiFdZiMMJmDDfY@hotmail.com',
#   'Email_LyIZOLfcwizwmw@yahoo.com',
#   'Email_MpUIUCJkyuFsYaR@yahoo.com',
#   'Email_MrKZblHunyhL@gmail.com',
#   'Email_NyDMJRuHna@qq.com',
#   'Email_YHFComoaatjyKcsq@yahoo.com',
#   'Email_YdmvgFSdFXqKTciQbdh@qq.com',
#   'Email_ZoiwTIlcrDhNFPTPwUjL@qq.com',
#   'Email_bUiYQYOtRqSOJikaMlfT@yahoo.com',
#   'Email_fBAdjEJbOnFcTxnEpok@yahoo.com',
#   'Email_mtDNHktZqFFpCP@yahoo.com',
#   'Email_wVTYmwo@yahoo.com',
#   'OrderId_BnOvlLUnaKBCFTSmZpBkgjoVW',
#   'OrderId_BpbQNtvVUwHQsZEPEnsLDRLBX',
#   'OrderId_RJzrzxVPZgleARdRdXTnONOeN',
#   'OrderId_TXxHDrOPkLbcGhZzeMQsgzBoP',
#   'OrderId_WcDrxXHgTmlmsStFdMCxXXxKF',
#   'OrderId_XXDsDUJBbiKxaPCYspyIPVaLL',
#   'OrderId_XlEVoaWTJJkNlbMUXllrnUyoD',
#   'OrderId_YrAiCovEUpOJnotbSdtStWcTF',
#   'OrderId_aEwOVgWvkVauMPdLGikAePBNJ',
#   'OrderId_bXAjSZkcKmezvqVdWQViLkZdv',
#   'OrderId_cLtQwEvNwiAwNpISJaIJDoyXk',
#   'OrderId_fqLaEbVXpvALfevmpteLmFykp',
#   'OrderId_mcbkjoGVbbyEMfmzqgoaramwn',
#   'OrderId_pbzomItoEbFhxwhePyyOpNggy',
#   'OrderId_ubbqZfrKAfVOKfSjONDBkezhs',
#   'OrderId_wKqYRFqSSEDEHFcZcrCqkwrED',
#   'Phone_375410845',
#   'Phone_42071062150',
#   'Phone_481227324',
#   'Phone_48858697665',
#   'Phone_54972231750',
#   'Phone_5767663286',
#   'Phone_7193665815',
#   'Phone_7680584493',
#   'Phone_8391574879',
#   'Phone_86036284495'},
#  {179, 'Email_OgJXtMVoImkDDPIGCsE@qq.com', 'Phone_52139134326'},
#  {14872,
#   180,
#   268358,
#   415071,
#   'Email_BfcqwoWHUkJOBYBo@qq.com',
#   'Email_RfQJnhaRfXna@yahoo.com',
#   'Email_ZeNxEoitYSiUQmYwNOw@qq.com',
#   'OrderId_LTJpNzRAzSpXMPqBCpTBLDDkR',
#   'OrderId_einfSHAGPovVxnbTqgutWohYv',
#   'OrderId_qjWEXvjGveiokFXLpsQsoeoIX',
#   'Phone_2320193448'},
#  {181,
#   'Email_dBjvLojEYSaIoeUglcTl@hotmail.com',
#   'OrderId_MQsLHpUToATHthktTllhOIkdc'},
#  {107985,
#   182,
#   223401,
#   313867,
#   465204,
#   6268,
#   'Email_BEMBkDHBDHQOopjggwGV@hotmail.com',
#   'Email_KaUrtcXyjPAQbUscrSD@gmail.com',
#   'OrderId_ExlRiYUQZAbakAHDvFqwqtIRD',
#   'OrderId_wTdMkVfnHqSxqhTAZiUmcNPvI',
#   'Phone_633769805909'},
#  {176299,
#   183,
#   221556,
#   30462,
#   351621,
#   406688,
#   407066,
#   41173,
#   476029,
#   483939,
#   86814,
#   'Email_EebrzuWSm@gmail.com',
#   'Email_LftqfksmizDXiCVA@qq.com',
#   'Email_YhvYpZbEBGidOBX@qq.com',
#   'Email_hkQsfNSPLsKydh@yahoo.com',
#   'Email_sVzTRzTvsMgCs@qq.com',
#   'OrderId_EHvXqRdckRlCSVLxILVsZxsdX',
#   'OrderId_EYPUybTHNZxGSXczWoudzXYfV',
#   'OrderId_pRMuzmqLxkMOzxHgmnForGhPU',
#   'Phone_133539439',
#   'Phone_436902227',
#   'Phone_6482371355',
#   'Phone_891019752'},
#  {184,
#   405992,
#   'Email_xtlqSaibn@gmail.com',
#   'OrderId_kMFUAFeGoGLEMzcyCDLWzznLW',
#   'Phone_20460347418'},
#  {118012,
#   13333,
#   185,
#   203759,
#   288495,
#   356636,
#   360010,
#   496266,
#   'Email_SRdNLRPANzVWHSf@hotmail.com',
#   'Email_TFGBFefNbxrU@gmail.com',
#   'Email_nlvuLRStZMmf@gmail.com',
#   'OrderId_DshKIuxwnTFBRvfwZiUmyOtrS',
#   'OrderId_UPehrRwBcxKvVDvgdPBNFfyDN',
#   'Phone_276136654128',
#   'Phone_429905319576',
#   'Phone_44381164063',
#   'Phone_9484825857'},
#  {186, 'Phone_1022280541'},
#  {111412,
#   187,
#   'Email_yRGQETZ@gmail.com',
#   'Phone_082673173',
#   'Phone_4752016761'},
#  {188, 'Phone_659777840469'},
#  {189, 'Email_RpYtReINelki@yahoo.com'},
#  {119170,
#   16313,
#   190,
#   201448,
#   295936,
#   437023,
#   437671,
#   'Email_XVaimZuHviFtxUGFJ@yahoo.com',
#   'Email_ZcSbCxeQP@gmail.com',
#   'OrderId_PcVIHIgWhJLYxXexnBNgkvoAS',
#   'OrderId_WefHubHdfqDUUNySNMpILoCKE',
#   'Phone_389779841',
#   'Phone_4414885628'},
#  {191, 'Email_vSBccbMssX@qq.com'},
#  {173505,
#   174551,
#   192,
#   257865,
#   291979,
#   'Email_BzxcluLMDXBwP@qq.com',
#   'Email_UYIYvQRNLyxSZ@gmail.com',
#   'OrderId_DafGdEXCcKlhiEmGGHTOAAznh',
#   'OrderId_WknCJNyJWqFHFjjVFVibgwWav',
#   'OrderId_bCqTjJnOjZsAvBMXGJRzGpfTd',
#   'OrderId_vmgbDiHNvFdYRpLPFTeQvvAZW',
#   'Phone_096234395',
#   'Phone_657252900',
#   'Phone_73052077008'},
#  {193,
#   79361,
#   'Email_HDGVsgSM@yahoo.com',
#   'OrderId_ZkTExjPIXyveXVhKeUtVvvXTD',
#   'Phone_789794237109'},
#  {194,
#   205205,
#   4132,
#   'Email_BKDzGeD@qq.com',
#   'OrderId_vLQFNOZernMPbqVcQDjtlMbhv',
#   'Phone_568788202033'},
#  {195, 'Email_kjJuaCnMbCOxXWqCsRP@gmail.com'},
#  {101723,
#   115356,
#   150332,
#   196,
#   269570,
#   290992,
#   291687,
#   359225,
#   'Email_SXyTbZDuLcCJDN@hotmail.com',
#   'Email_UVuXpferwOu@hotmail.com',
#   'Email_ZBUbDwcRdcCaJqJSxldf@gmail.com',
#   'OrderId_LAJDgTVKYtCkmySqaRjTdcXgc',
#   'OrderId_nAifturBkODQwAUJRtrzDppob',
#   'OrderId_pewGOjoxCGlOkwCwHEXpsNnSv',
#   'OrderId_uGaXYxicXyJWwANZqPxTNwyZT',
#   'Phone_577773388106'},
#  {197, 'Email_mmtGKiIMd@gmail.com'},
#  {194903,
#   198,
#   360906,
#   'Email_CsvsKiGoutqRFhUEqZY@yahoo.com',
#   'OrderId_BIWzIGnPNekqiXCgmXynVYgiN',
#   'Phone_83403821822'},
#  {199, 'Email_PVFjHle@gmail.com'},
#  {200, 'Phone_52721137328'},
#  {104000,
#   17801,
#   201,
#   22963,
#   284402,
#   291787,
#   29354,
#   307533,
#   32129,
#   337149,
#   373534,
#   403554,
#   4060,
#   409992,
#   58057,
#   66410,
#   87399,
#   94480,
#   'Email_BBbMdvNgEPISwjJvqNTy@hotmail.com',
#   'Email_KVsAGvJ@qq.com',
#   'Email_MUnYCsrlfr@hotmail.com',
#   'Email_QXdrNKlpY@qq.com',
#   'Email_VHmGCKbkwsagVcimzwAM@qq.com',
#   'Email_keNIxVGh@gmail.com',
#   'Email_qcwTskkjrDDomiYwOWa@gmail.com',
#   'Email_sAvFqHBltzEctNwMAc@qq.com',
#   'Email_zbdPskNXHwOzcN@gmail.com',
#   'OrderId_ABmmFyaZwyMifdAjvZVZOBVGa',
#   'OrderId_RUNscamfXnwuZrxnnGRpXWgoB',
#   'OrderId_cevJLClgJLFyScCyLvkHWfiIX',
#   'OrderId_dKcZXJGHeUFmFUfBuagIcVUIn',
#   'OrderId_fTouuVlNDqbZEXemlCrhavvrb',
#   'OrderId_wvJYDTYIFjBbxqaVkyFfHmeHw',
#   'OrderId_xGnQHhdNuvZhErlNVRmyEdrFC',
#   'OrderId_ynLQCEqbJzFLlJuHumQdRpRqi',
#   'Phone_252894406837',
#   'Phone_2677151487',
#   'Phone_9946917308'},
#  {202, 'Email_iAlPcekUqiiahYqMmLx@qq.com'},
#  {203,
#   'Email_nHbayrGZcDKaHOZw@gmail.com',
#   'OrderId_cZwenXGKcsFLmcwmIPuaPBTIl'},
#  {11043,
#   204,
#   212977,
#   22817,
#   254444,
#   254647,
#   260819,
#   320826,
#   324003,
#   336670,
#   374217,
#   3869,
#   61387,
#   'Email_CNjXSxmgQd@yahoo.com',
#   'Email_VykddOefGYjCiTUiXefu@yahoo.com',
#   'Email_bHzSbddJuWdajp@yahoo.com',
#   'Email_lkLdEtLax@yahoo.com',
#   'OrderId_MHRWKjizgUhOFAnabMfSTPebU',
#   'OrderId_VjUbaenOaQbhExgRTIxKgsdpe',
#   'Phone_2241644942',
#   'Phone_3583328969',
#   'Phone_769501784',
#   'Phone_937237242209',
#   'Phone_9602962383'},
#  {205,
#   215655,
#   252724,
#   354483,
#   372904,
#   465114,
#   51845,
#   559,
#   850,
#   'Email_GuJSbezLaPmGpCXH@qq.com',
#   'Email_KNFhZxVVnzHfnsm@qq.com',
#   'Email_XvTzEQKSoijUHLTyEog@yahoo.com',
#   'Email_nBUtYIIY@yahoo.com',
#   'OrderId_SWSvJnTmwGHxDFWneorYUaLxB',
#   'OrderId_XAkazFbgqgKseBfEOyQIeoNZr',
#   'OrderId_aHeZHDnZTKwizxUMOZlALSnRg',
#   'OrderId_htidLvmKVMfhESxoHmjkoUFtv',
#   'OrderId_uPmrxbgsdkhVRsCjWZQBgSqrj',
#   'Phone_6147688554',
#   'Phone_9862555880'},
#  {206, 'OrderId_ikcgUaoFVXGTOupDShjzDaWXP', 'Phone_3726073566'},
#  {207,
#   307378,
#   'Email_FfMciqCnoXRGBwvqFEh@yahoo.com',
#   'OrderId_NGSwvHkTvHicXxwgrcOLCOYpi',
#   'Phone_972631682'},
#  {208,
#   303253,
#   316869,
#   'Email_WspYaultUTzJLjGcARb@gmail.com',
#   'Phone_4635927349'},
#  {128312,
#   209,
#   444182,
#   459237,
#   7891,
#   98235,
#   'Email_zQgQlTQUXpcheXN@gmail.com',
#   'OrderId_IbSVQfUeqsSgJuQbSRWobWCjL',
#   'OrderId_lRHbgAMUjxBneUnEnaPmRnsYT',
#   'OrderId_sPOXqZJVjVWUvzBcpcAgEgxwd',
#   'Phone_725598392',
#   'Phone_846497487180'},
#  {210,
#   402055,
#   'Email_zaOWDcAUVPUu@hotmail.com',
#   'OrderId_QxbNllbOHXsOBRFbvDpuXORdc',
#   'OrderId_mIAvfYwVyCTzIRxxwWZzCfjFr',
#   'Phone_6077568766'},
#  {211, 'Email_vXKvClfAlcDp@yahoo.com'},
#  {212, 'OrderId_bcKOPOlYfnxsOfqHcTSJMSMyS', 'Phone_0592786149'},
#  {213,
#   480259,
#   96857,
#   'Email_WtArJhowrDvpT@gmail.com',
#   'OrderId_jTjzCxqxWfhcOcumWlVIbatAp',
#   'Phone_413602563'},
#  {214,
#   'Email_xgKHjQHxrlkHEXrz@yahoo.com',
#   'OrderId_ymmuIwnuvRMSizWRuGSciSxFL'},
#  {215, 'Email_zGbdujaLiBp@hotmail.com'},
#  {216, 'Email_lEIjcIIiGb@qq.com', 'Phone_6087719761'},
#  {217,
#   326355,
#   487124,
#   489730,
#   'Email_rJdDjCyeBNPF@qq.com',
#   'Email_vKcanmfAfdknkZFkIC@hotmail.com',
#   'OrderId_CiLfBURGokJztcsvOJDiJvvpr',
#   'OrderId_MoxfwxdTwERNjiKbqLDDXexUy',
#   'OrderId_QwAeGojlUpZiLlQaxQlwCMxuX'},
#  {218,
#   'Email_bJUtkaIgqANDdZxZ@hotmail.com',
#   'OrderId_BRsFsttNjksMMQFajEWGZSSJC'},
#  {219,
#   380008,
#   'Email_vJwcVFrxJFruvS@qq.com',
#   'OrderId_XZYxNRSavdsSYbZGpbDwWZxLX',
#   'OrderId_lQyFqSUsXnZsBsqhjRwoJpvpw'},
#  {220, 'OrderId_kOOTkDNehbPttKlirvszpRIif', 'Phone_412212188'},
#  {163948,
#   221,
#   334244,
#   64580,
#   'Email_jzzvYtZbn@gmail.com',
#   'OrderId_YStXDaLNdTDKyXyFRqWzzsMbm',
#   'OrderId_lhgkxMmDcbqLBTLbvpRUHXyse',
#   'Phone_0920243740'},
#  {147881,
#   17960,
#   222,
#   272867,
#   2787,
#   296001,
#   33581,
#   420735,
#   422982,
#   445542,
#   458888,
#   464908,
#   9181,
#   'Email_JWZtIvDoRkRW@hotmail.com',
#   'Email_QYUJbxXmalZhKiMZxxhJ@qq.com',
#   'Email_SwrukrCaJ@hotmail.com',
#   'Email_VsQMozniRQ@yahoo.com',
#   'Email_dLLnXiU@hotmail.com',
#   'Email_iyVzmuWIiJ@yahoo.com',
#   'Email_vQFWcYzOpFoouZICNmO@hotmail.com',
#   'Email_zXdqownq@yahoo.com',
#   'OrderId_EByroMopritisVMOkjFxokwKY',
#   'OrderId_GAkjJnQIFMbKZCJDQnTYQBKAm',
#   'Phone_25444720561',
#   'Phone_547507177563',
#   'Phone_5511161018',
#   'Phone_881388264'},
#  {223,
#   301712,
#   91460,
#   'Email_BTOlKGexiUefA@hotmail.com',
#   'OrderId_MolvMPQkQHclsVyzngjKCSweb'},
#  {224,
#   316595,
#   51435,
#   817,
#   'Email_bfeXwBW@hotmail.com',
#   'Email_fuqfhcsOJoUOAgHaAF@hotmail.com',
#   'OrderId_blULMBUlmMGEMGhcekgllOfYC',
#   'Phone_367408325175',
#   'Phone_6894400271'},
#  {225,
#   252674,
#   393542,
#   'Email_tGNfreDCYpri@yahoo.com',
#   'OrderId_bGRWFFctCXBUOhsiWlmmlZOQt',
#   'OrderId_smFNoHQNxJQuziWKIMWfsLdyO',
#   'Phone_982447401'},
#  {226, 'Phone_120896773523'},
#  {104845,
#   227,
#   344710,
#   46904,
#   57523,
#   'Email_QfvUeSS@gmail.com',
#   'Email_csrRLHOCFlrsl@gmail.com',
#   'OrderId_NiUsiwCpnnfiLfDGJxDSWYmVB',
#   'OrderId_TOGTDpMqBqgTjmMXfDOlrtdxb'},
#  {228,
#   236443,
#   490834,
#   'Email_GFzjloTGuNbwx@yahoo.com',
#   'Email_laKpGVatbiNAdbxj@hotmail.com',
#   'OrderId_PDqvbQFkYHhvHSiXWGZVuyYeW',
#   'OrderId_macgrlCkQFylzlHuQWSZUcGPY',
#   'Phone_02454528245',
#   'Phone_04361379082'},
#  {229, 260663, 'Email_nFzgNauMETZX@qq.com', 'Phone_732857460586'},
#  {190456,
#   230,
#   272016,
#   'Email_CddWjGZcmBGJdQDhZMZv@yahoo.com',
#   'Email_uNLqiaFcKAAGGKZc@qq.com',
#   'OrderId_IxgYjTBLsaOItOMjimukfsZVz'},
#  {222589,
#   230055,
#   231,
#   254384,
#   58285,
#   'Email_INadGamQWDppzg@qq.com',
#   'Email_ruFVmltJClGmroKj@yahoo.com',
#   'OrderId_CNaTbRwiYqJIKucVNEGknsWfu',
#   'OrderId_LGWCNkknJpNWmTynmZSCBtJbH',
#   'Phone_2922200984',
#   'Phone_4916480687'},
#  {203968,
#   232,
#   327056,
#   347654,
#   469710,
#   'Email_idfpPwtZapsErlrmwQ@yahoo.com',
#   'OrderId_BGXjtmupEtTfASopMnemvGSbJ',
#   'OrderId_OhgICbWCOAnMeIemXECZZNlwI',
#   'OrderId_ZNUjrukJxLRnpwqzGFnTquROs',
#   'OrderId_qBTQmtJiolEKxVaUXzVamHodQ',
#   'Phone_15937926884'},
#  {233, 484879, 'Email_JYuraoMujQBYUSmB@qq.com', 'Phone_415033125563'},
#  {165732,
#   233819,
#   234,
#   34171,
#   454479,
#   'Email_teJgzLZLcwCwUqhEr@qq.com',
#   'Email_wEhARZo@yahoo.com',
#   'OrderId_dGEEZsGFCkcQXHsvoqCKTWLLs',
#   'Phone_146385115'},
#  {141554,
#   198545,
#   235,
#   314321,
#   346872,
#   363038,
#   413468,
#   85009,
#   'Email_CoXbSutY@hotmail.com',
#   'Email_aHfgzfWli@hotmail.com',
#   'Email_jtJHXdOU@hotmail.com',
#   'Email_zKQvMWPGMFKpGYBoAZqE@qq.com',
#   'OrderId_OzMiFYRuUHEFiQCILveeYzlhN',
#   'OrderId_TNjxtRoUmkeUNeNNmzMaMdvaO',
#   'OrderId_VcjNSUKwQmAvfaGwIuYOLxlZd',
#   'OrderId_jpiLbQumRnnulEEvyYngctEdf',
#   'Phone_30848100139',
#   'Phone_895902623'},
#  {169662,
#   236,
#   23828,
#   351448,
#   87237,
#   87239,
#   'Email_QKTzfTw@hotmail.com',
#   'Email_zMbnfqbxdfnGhu@hotmail.com',
#   'OrderId_ChNHFfwyVHEnsjgOkNYtldpGa',
#   'OrderId_mUokLmtISfNEfrzDRbSdgdVUh',
#   'Phone_33193274126',
#   'Phone_80329551664'},
#  {22245,
#   237,
#   249023,
#   368510,
#   409086,
#   440015,
#   474266,
#   78477,
#   'Email_AfVtEgaSDZLoMAPHbKeA@hotmail.com',
#   'Email_BQGXytPvA@hotmail.com',
#   'Email_NomcWChWI@gmail.com',
#   'Email_aTwrUfDvCJscsMxQzYF@gmail.com',
#   'OrderId_IbzZPWpJFMLvEYsQmgFVkiMEx',
#   'OrderId_SYoTskUpGzGWZPjfVAcGHNYPO',
#   'OrderId_TDoaqljLoPZYAkvwtQSDbAWmX',
#   'Phone_351445539784',
#   'Phone_60997108622'},
#  {236143, 238, 'Email_YuHMEuRTCvFao@hotmail.com'},
#  {239, 'Email_JUIRuSggHLrqYpZGV@gmail.com'},
#  {157468,
#   240,
#   347261,
#   378121,
#   462828,
#   'Email_IcWSoIBlOkDvK@hotmail.com',
#   'Email_OpOsPiPqXSNy@gmail.com',
#   'OrderId_nUhRqGOriQiteQseOTtNnwABR',
#   'Phone_247496116'},
#  {168214, 241, 'Email_DkhGPQvgwbVvRVlh@yahoo.com', 'Phone_043565411'},
#  {242,
#   33469,
#   'Email_ZtpSgRuV@yahoo.com',
#   'OrderId_DrCQSiMsHuiwCvJQQXBcfkdNv',
#   'Phone_12817156677'},
#  {243,
#   386227,
#   390625,
#   'OrderId_AjsSLktWqVbYmhqdScAsdvmxF',
#   'OrderId_mgzEmtsBaGwdxzrVmdJZOtgBz',
#   'Phone_39218105117',
#   'Phone_871038711'},
#  {155428,
#   218572,
#   244,
#   458207,
#   'Email_RVuxIrJVGsQfu@gmail.com',
#   'OrderId_kzCnhFRevmubkJnjkLwvQjiyj',
#   'Phone_00124685005',
#   'Phone_056774325450'},
#  {170587, 245, 'Email_BIHEnXEI@yahoo.com', 'Phone_368246648'},
#  {184678,
#   247,
#   261881,
#   302311,
#   328828,
#   471943,
#   'Email_mKXmVoCdWkQc@yahoo.com',
#   'Email_mTXmlgDAxNaXiyVp@yahoo.com',
#   'OrderId_aSbDsSYfdNhKWKpWcejrKBadG',
#   'OrderId_rcaUYsjZkeLicJwMkHzOdvfFr',
#   'OrderId_xKLicMHMWDWCrZQcNWkjSLcEU'},
#  {248,
#   343852,
#   42707,
#   97987,
#   'Email_rRcSglC@yahoo.com',
#   'OrderId_SxQZEYcALTcIeGshHtlwMKOYZ',
# ...
#   917,
#   'Email_FBuTGNpDAHcoZQtAyNHC@gmail.com',
#   'OrderId_uZzNapAADJTGXyUSudGcEeSFv'},
#  {244409, 918, 'Email_ITirLVlo@gmail.com'},
#  {136067,
#   255800,
#   261816,
#   8550,
#   919,
#   'Email_wqyyfRwkpQSDbCe@hotmail.com',
#   'OrderId_MqoUJBXwlWohOZVtupcFspAXD',
#   'OrderId_sSdPecasqPioMyeJBDcinSPUN',
#   'Phone_547938274',
#   'Phone_841102675612'},
#  {920, 'Email_UXuLlcSlnsQvLy@gmail.com'},
#  {376585,
#   444459,
#   921,
#   'Email_pExsvDBIehXS@gmail.com',
#   'OrderId_NMulmsBsZDWximPVigSElbUwu',
#   'OrderId_amBJgdiLhkSzlDhxoVmxVYyyX',
#   'OrderId_dVVSaTDBnUWPgNOUTkykPYJhm',
#   'Phone_7096807127'},
#  {249994,
#   922,
#   'Email_jtsGeptMvgHod@gmail.com',
#   'OrderId_xkbIqdWAcKMHenUmfLZqUswVv'},
#  {923, 'OrderId_mHTVlOUjuZyWUmbYzpRzpRRPt', 'Phone_41105225653'},
#  {109486,
#   267326,
#   61937,
#   924,
#   'Email_DXBkBzOGJVjfDcB@qq.com',
#   'Phone_560263929847'},
#  {16251,
#   429534,
#   925,
#   'Email_TMmjlYbTVyiTkrRaiYYv@gmail.com',
#   'OrderId_UltVhGxbAixRBuKNtYrYAscXL'},
#  {32156,
#   431788,
#   926,
#   'Email_fZBFdJAXWUABHUUTkUa@hotmail.com',
#   'OrderId_XZIGgiIgdwqHLxRRJaFMduOwO',
#   'Phone_7023126269'},
#  {10415,
#   109890,
#   121427,
#   156582,
#   165693,
#   194112,
#   220409,
#   231434,
#   24381,
#   297737,
#   31886,
#   323684,
#   338762,
#   351247,
#   396970,
#   409302,
#   41021,
#   412669,
#   42947,
#   483337,
#   496168,
#   5227,
#   62704,
#   927,
#   'Email_AeqsoAdKPVlUl@qq.com',
#   'Email_OOXKODFHpgVuvQCpSAf@yahoo.com',
#   'Email_QuLMHzVBHDJ@yahoo.com',
#   'Email_SKuHuIkHZSOgH@hotmail.com',
#   'Email_SmNGceWmWr@yahoo.com',
#   'Email_UGPeCrGlRcSKCau@yahoo.com',
#   'Email_YEYRyImMZCsT@yahoo.com',
#   'Email_bWvulwWTpKBlzLbZSlpR@hotmail.com',
#   'Email_cwJNtnlaDtrQJKkvyG@gmail.com',
#   'Email_hDgJAmhJYmdeFpl@yahoo.com',
#   'Email_ojRJMDysKtpiY@qq.com',
#   'Email_sWJXyolVxaMr@yahoo.com',
#   'OrderId_EtdYIAaMcpshztEEnLqXLvirt',
#   'OrderId_KxzwYtqTrSuwOnuBgseEysyFI',
#   'OrderId_LwILiJgyVsPUPRLSfRgsisAUa',
#   'OrderId_OYaMoCsZRVsZaDWJKRtQjiUcg',
#   'OrderId_QbhlbzmvwCCjwpUcPtRFxNsVX',
#   'OrderId_dGnhjUfXOBTorEyCXBeyMnQVO',
#   'OrderId_fsGvpFZLkkvANENxWUTgvvAZn',
#   'OrderId_lqIuLSKCSsiMDAXmbxJsjDYYr',
#   'OrderId_oxdrMCtmixVYqkJahFfyaLOoP',
#   'OrderId_wONGLGlkGwKqhrKHmaBorIcHi',
#   'OrderId_zEFQtUxWieXKDuABUILRwzURf',
#   'Phone_056211992',
#   'Phone_192119291',
#   'Phone_561802558899',
#   'Phone_774240720769'},
#  {928, 'Email_qdUGqrHgDZMgyMLdvx@qq.com'},
#  {929, 'Email_NhaqFnKotIES@qq.com', 'Phone_6309699274'},
#  {930, 'Email_jWuNGWC@hotmail.com'},
#  {931,
#   'Email_WySSQLcWbiGbVnLrgftr@hotmail.com',
#   'OrderId_WNHKLRViGgNuZVLtKbfosUdwj'},
#  {932, 'Phone_6410921779'},
#  {358304,
#   449522,
#   7168,
#   933,
#   'Email_fgAuDoUzmvvh@yahoo.com',
#   'Email_hTohwiZ@gmail.com',
#   'Email_ukWhudv@yahoo.com',
#   'OrderId_MrobehbPpkwJcJTrFoCYidpCB',
#   'Phone_40195904670'},
#  {934, 'Email_ykKQhSNJelwQmAALj@gmail.com', 'Phone_645441238'},
#  {936, 'Email_rJFIcjprXOGJcVURzj@hotmail.com'},
#  {340564,
#   938,
#   'Email_oQVQrQc@yahoo.com',
#   'OrderId_HhJWjhBJYxRyvDKvApgozygQT',
#   'OrderId_bHScXNGbRJgEXxkYFGvTIALpZ'},
#  {129428,
#   169152,
#   380751,
#   453147,
#   465194,
#   59940,
#   939,
#   'Email_QAoInkzBxjOZj@yahoo.com',
#   'Email_RLExiIrXzmFw@gmail.com',
#   'OrderId_AawGywvHhOZgDRjwgdlpAQpOu',
#   'OrderId_jTvzpBuGYlpEcDnhMGIhodhEg',
#   'OrderId_zrOPdRabPHwKWfWjEyPReFAna',
#   'Phone_08716157452',
#   'Phone_5090790420'},
#  {18536,
#   495306,
#   940,
#   'Email_eiCHfwduQlMMqiDG@hotmail.com',
#   'Email_pDOMgOxryulkCiGY@gmail.com',
#   'OrderId_wHRUEYcToCBGaBpnyulwKMmOg',
#   'Phone_064952984917',
#   'Phone_45084316372'},
#  {179963,
#   345507,
#   429157,
#   446784,
#   82277,
#   941,
#   'Email_LAFZgkU@hotmail.com',
#   'Email_LHadhAqudBV@yahoo.com',
#   'Email_aLYIxZLFqiEUi@yahoo.com',
#   'OrderId_PMlYtgpCOzrRlfXNqgrDWkQAz',
#   'OrderId_VLvolQMGdpKFaebRcLdwfaYzW',
#   'Phone_212609642',
#   'Phone_976525658481'},
#  {942, 'Email_TVLQWNsI@hotmail.com', 'Phone_3754679895'},
#  {257446,
#   296970,
#   943,
#   'Email_vWdcIrStDrbg@yahoo.com',
#   'OrderId_TfihZDvhAQRHmJlbvkfacmwWq',
#   'Phone_048986551'},
#  {123018,
#   456280,
#   479350,
#   944,
#   'Email_CavBXrO@hotmail.com',
#   'OrderId_uYTKMMBEWoQcGjTqHSvVArQmE',
#   'Phone_421845962'},
#  {114540, 945, 'Email_YnidpetMgrqPSUi@qq.com'},
#  {152515,
#   946,
#   'Email_pXxamfeXaAVaJqTtzHiL@gmail.com',
#   'OrderId_YhxoKLdlXbHEWyrodPCVGiYND',
#   'Phone_57302277754'},
#  {237238,
#   239507,
#   30990,
#   44620,
#   50530,
#   947,
#   'Email_ILOeIzRmjXABuMAWN@hotmail.com',
#   'Email_lZmDmmnHor@gmail.com',
#   'Email_rRjuUEztzKCnes@qq.com',
#   'OrderId_EAnRZHYlalQHFJeaAtJUBECWG',
#   'OrderId_pieNUVjUQMywQgoDPmFTWsiah',
#   'Phone_201371818',
#   'Phone_375787276',
#   'Phone_55702466323',
#   'Phone_685377209'},
#  {270949, 948, 'Email_aFyGRqgOIVURxelC@hotmail.com'},
#  {949, 'Email_SburRdNCxMpYsCm@yahoo.com', 'Phone_207513450805'},
#  {10902,
#   1479,
#   210605,
#   227087,
#   279738,
#   291586,
#   383323,
#   409970,
#   950,
#   'Email_KqKbUmgy@hotmail.com',
#   'Email_gfhAwKdjoLk@qq.com',
#   'Email_qzaZQESFLkAMkjDoNyD@hotmail.com',
#   'OrderId_CAmPuUnpLwIumZapuhPqsneph',
#   'OrderId_JESHsyDfPufvISdRuXjCXChOz',
#   'OrderId_YbpJuvQuIiGavRjWXdJKMSxec',
#   'OrderId_dwCWGjOEEeCVLzBpDOprjRCSR',
#   'OrderId_tmRUqHSHkrMWuQoMQkhMOmHTk',
#   'OrderId_zQrkstVnuKEPaHTBAgfJzGsYC',
#   'Phone_40531804702',
#   'Phone_597354579903'},
#  {218717,
#   341555,
#   405270,
#   951,
#   'Email_VfUYVWPteVQksGcFi@qq.com',
#   'Email_wYdDUTBtIFqPvYduCI@yahoo.com',
#   'OrderId_AcbNvWWEIoSMNjSIiQCKrfLXo',
#   'OrderId_FhXaRUwihyHJuhcTThTpoTtHn',
#   'OrderId_NjWMulCvqPQguGCyAPVkXtvjO',
#   'Phone_0955992034'},
#  {482702,
#   952,
#   'Email_nodLDyZAPtibFWpRqNd@hotmail.com',
#   'OrderId_hDyUhieXSBthkCnvaBeLCAIAF',
#   'Phone_11991713852'},
#  {100893,
#   143552,
#   151550,
#   205140,
#   234473,
#   293187,
#   297180,
#   353282,
#   483338,
#   492764,
#   953,
#   'Email_ijzVENrWvLiXXHd@yahoo.com',
#   'Email_kHlUHRQrhtvvZc@qq.com',
#   'Email_mUXBqee@gmail.com',
#   'Email_rzyDBFKIrEIP@qq.com',
#   'Email_xFesJxvVHqvQdwPOi@qq.com',
#   'Email_yjpzFHpJ@hotmail.com',
#   'OrderId_LwLTwxJNhXIfuriECixAkyEgR',
#   'OrderId_RUbDgNuXxTfjZCKTZrfNnPMYe',
#   'OrderId_WSmSFFpiAWQFHYYSBiiYlQPbm',
#   'OrderId_yHqNNWUWxgZbgKPhGbrryEqvo',
#   'Phone_0764019234',
#   'Phone_0779483534',
#   'Phone_141221538',
#   'Phone_28984798604'},
#  {954, 'Email_vAdVJpotya@qq.com'},
#  {258019,
#   404288,
#   955,
#   'Email_VQcYHUwEnAuUVAnDMcCt@hotmail.com',
#   'OrderId_zFXJEQrvDEKCrMvwxHKIWQpXu'},
#  {118604,
#   12279,
#   956,
#   'Email_eZmJziIYdjxrZpwQ@gmail.com',
#   'Email_klaUOTTZGkRrutioFa@qq.com',
#   'OrderId_stEECyuhpvjoppdbKgMHoUICd'},
#  {138680,
#   249248,
#   268233,
#   373900,
#   491648,
#   957,
#   'Email_COHUQlUrLiIkx@qq.com',
#   'Email_MFoCpijzDaOhvUMhvrU@qq.com',
#   'OrderId_DaJxbdizwqGZlgwoJYMhIzxee',
#   'OrderId_FhJpKouPhSGyTzlGfbruZtdMI',
#   'OrderId_inquXoCCXcSDdIQFrivYPJwss',
#   'Phone_39124762955'},
#  {102796,
#   114387,
#   119887,
#   227272,
#   268019,
#   302983,
#   329934,
#   349543,
#   42168,
#   44071,
#   455436,
#   463893,
#   59420,
#   72274,
#   83363,
#   958,
#   'Email_ABXXfaNonYTdFAzkE@hotmail.com',
#   'Email_XkURLKfbtygbhih@qq.com',
#   'Email_bdbAwRPUrD@yahoo.com',
#   'Email_eVZhMIBHpmizfFQv@hotmail.com',
#   'Email_hZskOOIcEwcjnMvTYB@hotmail.com',
#   'Email_yDVEhoggUDPvpN@yahoo.com',
#   'OrderId_HquzyjtKASzRgXfqkOQosFhID',
#   'OrderId_IhRVICGogQLiadrCATDIlILiv',
#   'OrderId_XSUQupnjRutPxewZcXVMsTrhe',
#   'OrderId_kskfiKKoKnzFVYAUXoXeeKOwL',
#   'OrderId_wbhbsFcDPZnIAkLkRkxGAfbcF',
#   'Phone_0910083400',
#   'Phone_122630383611',
#   'Phone_23293833751',
#   'Phone_469836235',
#   'Phone_489345386',
#   'Phone_5977923023',
#   'Phone_645604343',
#   'Phone_89134384120'},
#  {959, 'Email_GWCfFtLQFlH@hotmail.com', 'Phone_4634326920'},
#  {247253,
#   960,
#   'Email_ifvcPzCQM@gmail.com',
#   'Email_jCMFLEmQOJqzAL@hotmail.com',
#   'Phone_191003098176'},
#  {961, 'Phone_848376003015'},
#  {962, 'Email_yGfSeByluiqCojHf@hotmail.com', 'Phone_101926772'},
#  {963, 'Email_tBTNOdWCzjJNSr@yahoo.com'},
#  {13953,
#   281484,
#   964,
#   'Email_DcQwTLSsy@yahoo.com',
#   'Email_rgQHzxMNWxoHUaq@hotmail.com',
#   'OrderId_pJZbAJSiOqaoQdpTsFchuJOHc',
#   'Phone_623797071280'},
#  {965, 'Phone_372024396894'},
#  {966, 'Email_iHpqonFXIOxV@gmail.com', 'OrderId_VtPeVpIyrRKJzpSwXkaHCHgZt'},
#  {140597,
#   208715,
#   268516,
#   298014,
#   460088,
#   64910,
#   967,
#   'Email_JmcLaiHuSqsGt@gmail.com',
#   'Email_tbulWFSaWIGnORzUafkf@gmail.com',
#   'OrderId_mNDxsqSQOdhSenhSpYLwsWgVI',
#   'Phone_6308152161'},
#  {36371,
#   968,
#   'Email_gtFIXNfIWqJWMYcwpHA@hotmail.com',
#   'OrderId_IODqudTVZyhyuLSCsjCBYdSnd'},
#  {20692,
#   33446,
#   969,
#   'Email_BPImFhBBHPcb@yahoo.com',
#   'OrderId_yyPWCVUMvqopydWeusPrphZoR',
#   'Phone_365614151947',
#   'Phone_50528011013'},
#  {11481,
#   175497,
#   313830,
#   494495,
#   970,
#   'Email_CvWZEbfPswpQ@yahoo.com',
#   'Email_kiJiJdhMDSUVVwql@qq.com',
#   'Phone_840181053'},
#  {158299,
#   2890,
#   311659,
#   359073,
#   470681,
#   499923,
#   971,
#   'Email_imeBLKzkJtvGtefQudwX@yahoo.com',
#   'Email_tLzzsGJrkDOSdv@yahoo.com',
#   'OrderId_CbBBbruXOlxcWZnzQvpbcjbeB',
#   'Phone_309817487782',
#   'Phone_5992573714'},
#  {114914,
#   209335,
#   26395,
#   275495,
#   302572,
#   326000,
#   371404,
#   386125,
#   426836,
#   453002,
#   463202,
#   484081,
#   488567,
#   66188,
#   75443,
#   972,
#   'Email_HLRqANgPzTFOIxvwZwHE@qq.com',
#   'Email_QTvYWREIwERWrdrmNW@qq.com',
#   'Email_RUOQnKClcBXQICEzRJU@hotmail.com',
#   'Email_UndJRIYQAAfrdtQ@yahoo.com',
#   'Email_VTPAPTuYkcqFpDBHQq@yahoo.com',
#   'OrderId_ElzgocBOmhpgHBHbeYUfLyIUY',
#   'OrderId_TYEiObfrxleNxWYFxKMJEsqNB',
#   'OrderId_dMJIfZtqlpAtNIERKnPAVylrk',
#   'OrderId_nBaHhIBqmayZzNUuqKoGsfUKm',
#   'OrderId_nFhADDXNItahsIWtmcAdLAQBx',
#   'OrderId_qBetUUkauBZeyzzOIlWZRnMKw',
#   'Phone_121985175',
#   'Phone_1390755644',
#   'Phone_44423591231',
#   'Phone_87485444792',
#   'Phone_995580019021'},
#  {973, 'Email_CRpQrJjptMdkxzf@qq.com', 'OrderId_SofeSZRYWPuGsXAUjlpIXfCgT'},
#  {468707,
#   974,
#   'Email_vmvuZBLruG@hotmail.com',
#   'OrderId_FKGdBbbCeItotFuNvVcoVSVrY',
#   'OrderId_UpfkyjOvEFhDGtzrvlAHRBIFd'},
#  {975, 'Phone_414780852'},
#  {141996,
#   148164,
#   252077,
#   270360,
#   384338,
#   491221,
#   75287,
#   976,
#   'Email_RGmKRGcAp@qq.com',
#   'Email_RVYFBYVTQ@gmail.com',
#   'Email_zYhfZkHqudriuHsAwnqm@qq.com',
#   'OrderId_KgwJNoWBsWvtMHCnLSwbgUSWA',
#   'OrderId_OZeKZJGGqJYuaAnHVtAhuVnGd',
#   'OrderId_ZdqlqdFkmTPwTaABxAEMASFFw',
#   'Phone_69732332372',
#   'Phone_96743734916'},
#  {977, 'Email_kHgYymb@qq.com', 'OrderId_VxuqoIJnwEaBuyPUeTWljwDER'},
#  {149879,
#   225579,
#   303480,
#   486790,
#   492578,
#   52331,
#   978,
#   'Email_hpfKwHeIrAjiiEDwgCS@gmail.com',
#   'OrderId_FfxjuDRYtrwBDANtFXLIFAvjK',
#   'OrderId_hkKPsIPuvrqgIXWaevQFrUPVg',
#   'Phone_490215366',
#   'Phone_592010954',
#   'Phone_710185961',
#   'Phone_78139354918'},
#  {150740,
#   151788,
#   162138,
#   183153,
#   209426,
#   21667,
#   296260,
#   340064,
#   409339,
#   416878,
#   492293,
#   5698,
#   979,
#   'Email_PmNgGvX@hotmail.com',
#   'Email_SpsFXZRT@gmail.com',
#   'Email_lQoYjovUrtokEJRHeHyc@hotmail.com',
#   'Email_phZCCzwItQJuYy@yahoo.com',
#   'OrderId_JVGnBsdMbkJkipFQtOisBUjcF',
#   'OrderId_VsEjJDEuoYszQRXqXxKmsMzUv',
#   'OrderId_hHIuUZqpXFJvragOjjkvVKTUF',
#   'OrderId_txchQmRBIEJPrJAuLzqEiUbsP',
#   'OrderId_zrOUOQvzWAbswWHmAICoZwuQv',
#   'Phone_1130175420',
#   'Phone_219650980',
#   'Phone_5522174032',
#   'Phone_920912492'},
#  {93879, 980, 'Phone_35244643635'},
#  {113575,
#   197744,
#   227697,
#   251588,
#   258544,
#   272022,
#   2895,
#   307361,
#   309505,
#   36429,
#   3859,
#   469842,
#   71682,
#   97485,
#   981,
#   'Email_CCKVXZWGD@yahoo.com',
#   'Email_RoUvEzKGIngnfrQpcaOA@gmail.com',
#   'Email_XlPaASrRFzCAfQTInibX@hotmail.com',
#   'Email_ajzcNEWFNkChVMdEzT@qq.com',
#   'Email_bOWDFjqLLWh@gmail.com',
#   'Email_jAYAkZKROSvFCgoOr@qq.com',
#   'OrderId_CEeKfSYWntUdOaQCvEmmOpSrk',
#   'OrderId_JmlXSXTXbDoqZwydGKpNWuDwi',
#   'OrderId_RLriqpnpMThZJulbbToUGByus',
#   'OrderId_UIUHQDYlLAjYtEJBHXHXfBvmD',
#   'OrderId_cmhowkBAgRrNytKlUQzUPgfjS',
#   'OrderId_nrhwkDMcksluLQNGUFgqgFBgo',
#   'OrderId_pMRKGJzGbalwZYdsAprhNJYGk',
#   'Phone_42391074862',
#   'Phone_521080766026',
#   'Phone_998114170941'},
#  {982, 'OrderId_aPJGoCAjYSyEfawKYZRzKpgFj', 'Phone_762966955852'},
#  {983, 'Email_aDItuzzvSKLeehU@gmail.com'},
#  {984, 'Phone_60880732962'},
#  {985, 'OrderId_fXPrURbRKocCOhRPQhTQgwCPc', 'Phone_82021892528'},
#  {986, 'Email_QhKIAuloOLIt@qq.com'},
#  {987, 'Email_dEQdESXVfZOHavLjU@hotmail.com'},
#  {285906,
#   988,
#   'Email_cDiGvwTA@hotmail.com',
#   'OrderId_EFFpHYxqyArJsLIUAtulVMkBF'},
#  {158990,
#   225789,
#   375182,
#   455559,
#   989,
#   'Email_RILoPvHgfSMvXPVULtpx@yahoo.com',
#   'OrderId_LjvFzftCJFJtGVNcgELULxHZm',
#   'OrderId_fvSpPomuEoyaEDgAIKMJoUjmu',
#   'Phone_0111091752'},
#  {990, 'Email_PuBkubZVFOagK@gmail.com'},
#  {141480,
#   262252,
#   2944,
#   496087,
#   991,
#   'Email_hTPXxOsjmzNtkXGoGa@yahoo.com',
#   'Email_lVPJWYl@hotmail.com',
#   'Email_lYdYBUA@qq.com',
#   'Email_rdTkifqIytWdXyS@qq.com',
#   'OrderId_VFibgONUtkLYYOHzLfqasLifE',
#   'Phone_62186942101',
#   'Phone_730897883',
#   'Phone_93384806594'},
#  {129495,
#   27166,
#   293629,
#   359275,
#   368404,
#   396869,
#   420105,
#   97073,
#   992,
#   'Email_OfkBNsVTBHDg@yahoo.com',
#   'Email_gFcqTlVH@qq.com',
#   'OrderId_AnQFiIxNfEsxfsOABvyuNLzsO',
#   'OrderId_EzdqFWcpfploprqNSzRwwoIqZ',
#   'OrderId_IfcxXcqpHEzVkMTKTyEsMkHyA',
#   'OrderId_TDmLmMbjxThNsFpDYraagigHU',
#   'OrderId_vzQcZszRLsJgCQFehpeuRrnqY',
#   'Phone_2077421466',
#   'Phone_325369962576',
#   'Phone_3764745213'},
#  {146500,
#   83513,
#   993,
#   'Email_EykKGkgsqpQbhVqnxumi@hotmail.com',
#   'Phone_13332300439'},
#  {994, 'Email_icgwbUYJYqFeht@gmail.com'},
#  {316304,
#   341113,
#   995,
#   'Email_TDOxyEushOfjuWWSfq@yahoo.com',
#   'Email_VpAQSBupYWAQx@gmail.com',
#   'OrderId_FWzciQSuuWVJfSIiniFXpcfXq',
#   'Phone_368418995637'},
#  {3500, 996, 'Email_DgNoWDAxXbZZFJoDOvq@yahoo.com', 'Phone_280341060'},
#  {997, 'Email_EKdmwQisoMHpfh@qq.com'},
#  {387554, 78821, 998, 'Email_NJVIYoiOiLJrZm@gmail.com'},
#  {999, 'Email_koavZBbRi@qq.com'},
#  {1000, 86254, 'Phone_753808605'},
#  {1001,
#   215949,
#   'Email_SDRcylKITJ@hotmail.com',
#   'OrderId_GuCyAKTjLRnKaWGIaSOKFjZic',
#   'OrderId_TKCZhAuFmBurLqbQNcMsMFHpx',
#   'Phone_425793843'},
#  {1002, 'Phone_3722461925'},
#  {1003, 'Email_GafXpmgXiYgq@qq.com'},
#  {1004, 'Email_WOhXRhhcrG@yahoo.com', 'Phone_8976120266'},
#  {1005,
#   114078,
#   369296,
#   60368,
#   'Email_PkGjgTDkDYS@hotmail.com',
#   'Email_sGSlweXLFJODyFOB@qq.com',
#   'OrderId_fTDztGTcunjuxnUJWEcLHumCV',
#   'Phone_004085184374'},
#  {1006,
#   333854,
#   341514,
#   'Email_DffbdBfRMFBlQuQDkgM@yahoo.com',
#   'Email_KjpFSIDqd@qq.com',
#   'OrderId_RthedKjlPQyciCllMGZYOZlgF',
#   'Phone_846800077'},
#  {1007,
#   260033,
#   'Email_aEJISojBZUTifon@gmail.com',
#   'OrderId_gifcViyWBGXkoJbAkAVqBRfzZ',
#   'Phone_46494266360'},
#  {1008, 'OrderId_FNDsskEMGIFaufxoHlzSVZCBn', 'Phone_535507215665'},
#  {1009,
#   1217,
#   136926,
#   370890,
#   389739,
#   424134,
#   'Email_VyeGRixWlggYRSQTaro@hotmail.com',
#   'OrderId_BPdGewpDqpGVtFCXPatUrrFmC',
#   'OrderId_CihCakFUgGncJFZnKsMbjzRJg',
#   'OrderId_IUMEMKUWQWkEbPZSZVOhIVAvl',
#   'Phone_28833536517',
#   'Phone_531193372629',
#   'Phone_9113345853'},
#  {1010, 'Phone_497761359000'},
#  {1011, 98362, 'Email_NeptQPgL@qq.com', 'OrderId_mRthvsdzEwEsreyOGQJcKVIjY'},
#  {1012, 210801, 'OrderId_FUyFWekbdwQCkIUjPzGsZASBU', 'Phone_80022099923'},
#  {1013,
#   'Email_CNuDtGApaHbzCLWBf@yahoo.com',
#   'OrderId_osMBvUswXcQoJXUenciBurhKZ'},
#  {1014, 'Phone_27286735222'},
#  {1015,
#   32623,
#   'Email_slUIdLczNPgcEBGbD@gmail.com',
#   'OrderId_khwcyxNRiABVfwCIOxKzVPPGN'},
#  {1016, 'Phone_080465461982'},
#  {1017, 'Phone_6911384890'},
#  {1018, 'Phone_762407451'},
#  {1019, 'Email_ItYbZzWSqvH@yahoo.com', 'OrderId_bExTvjeEkYdSrGIRuvDuBWCUP'},
#  {1020,
#   182086,
#   281534,
#   290804,
#   357555,
#   378820,
#   50003,
#   'Email_cwuAlbktsgei@hotmail.com',
#   'Email_yYFyeOYTpD@gmail.com',
#   'OrderId_YgxkRDToOYCqbwLsprMSpNckH',
#   'OrderId_glfThWSVqFeoqeplYOzrCIpUG',
#   'OrderId_pksMfUgnRJOPWdBwkJPaUkRpw',
#   'OrderId_tfhIElyocqdsgAahoOuTcwgCl',
#   'OrderId_uvQVSnrxHtCgCLqRnlwofYIpc',
#   'Phone_0402166769',
#   'Phone_451325717'},
#  {1021,
#   127096,
#   365496,
#   375750,
#   392952,
#   394567,
#   397937,
#   441202,
#   493040,
#   'Email_WFAApxEEtjJSNZjDS@hotmail.com',
#   'Email_cICudTkcqavBiPzSm@hotmail.com',
#   'Email_khkYHwSvFvn@hotmail.com',
#   'OrderId_TmTvfVPKTOcapvnBfKepDjTcN',
#   'OrderId_fMrVZJfMoVcLJVAcLcSnovdyA',
#   'OrderId_jdUdwVStHcCeUmMiGOEUcMRbL',
#   'Phone_1382455482',
#   'Phone_836553792'},
#  {1022, 'Phone_80954119177'},
#  {1023,
#   1940,
#   'Email_abmkSzsnAGeRws@gmail.com',
#   'OrderId_umnUxhHgGNlMXRneQHlwkWieG',
#   'Phone_6763576962'},
#  ...]

# %% [markdown]
# ## Extract the graph network
# The idea is one ticket_id one line, with their connected ticket id concated, number of contact points made summed up.
#
# For each connected component, i.e. each list, we concated the ticket_id within, and summed up the contact made (stored under the nodes attributes earlier)

# %%
output = []

# for each connected component, i.e. each list, we apended the ticket_id within (to concat in the later part)

for each_connected_component in conn_comp:
    
    id_list = []

    for each_node in each_connected_component:
        
        # check if the node is a number, append to the id_list
        
        if str(each_node).isnumeric():

            id_list.append(each_node)

    sum_of_contacts = 0
    
    for order_id in id_list:
        
        # summed up the attributes ie. contact made that belongs to the node
        
        sum_of_contacts += G.nodes[order_id]['Contacts']

    output_str = '-'.join([str(each_node) for each_node in sorted(id_list)]) + ', '  + str(sum_of_contacts)
    for order_id in id_list:

        output.append([order_id, output_str])

# %% [markdown]
# Convert the output as dataframe, and sorted according to the competition requirement, and exported as csv file.

# %%
output_final = pd.DataFrame(output)
output_final= output_final.rename(columns={0:'ticket_id', 1:'ticket_trace/contact'})

# %%
output_final.sort_values('ticket_id').to_csv('output.csv', index=False)
